# %%
import pandas as pd
import re
import os

# %%
# Sample file
sample = pd.read_excel('data\sample.xlsx')
print(sample.head())

# # reading hcs file(htmls, xls)
# with open('today2.xlsx', 'r') as file:
#     html_content = file.read()
# hcs_list = pd.read_html(html_content)
# hcs = hcs_list[0]

# # making first row as column
# hcs.columns = hcs.iloc[0]  # Set the first row as column names
# hcs = hcs[1:].reset_index(drop=True)  # Remove the first row and reset index
# hcs.head()

# print(hcs.describe())

# reading text file
# Out:
#   ISSTYPE  CARD_NUMBER          CRDH_NAME       ATM_ACCT    ISS_DATE  \
# 0     NEW    110120130  Ram Prasad Khatri  B001002104600  2025-03-18
#
#    EXPIR_DATE  CARD_ID
# 0  2030-03-18  XXXXXXX
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[4], line 7
#       5 # reading hcs file(htmls, xls)
#       6 with open('today2.xlsx', 'r') as file:
# ----> 7     html_content = file.read()
#       8 hcs_list = pd.read_html(html_content)
#       9 hcs = hcs_list[0]
#
# File C:\ProgramData\anaconda3\lib\encodings\cp1252.py:23, in IncrementalDecoder.decode(self, input, final)
#      22 def decode(self, input, final=False):
# ---> 23     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x9d in position 16: character maps to <undefined>

# %%
hcs = pd.read_excel('today2.xlsx')
# hcs.describe()
hcs.head()
# Out:
#    ISSTYPE       CARD_NUMBER             CRDH_NAME         ATM_ACCT  \
# 0  REPLACE  4753960000746392           IJAJ HUSSEN  414701406417018
# 1  REPLACE  4753960000742094  TEJLAXMI RAJBHANDARI  210200053905015
# 2  REPLACE  4753960000742102  PURNA BAHADUR KHADGI  210201108720016
# 3  REPLACE  4753960000742193    SUKRA P. RANJITKAR  210001312381019
# 4  REPLACE  4753960000742219        BISHNU B SINGH  726105035139015
#
#      ISS_DATE  EXPIR_DATE  CARD_ID
# 0  2025-03-24  2029-03-24  1308014
# 1  2025-03-24  2029-03-24  1306670
# 2  2025-03-24  2029-03-24  1306671
# 3  2025-03-24  2029-03-24  1306678
# 4  2025-03-24  2029-03-24  1306680

# %%
# This is for single file input

# # Ask user for the text file path
# txt_path = input("Please enter the path to your space-separated .txt file: ")

# # Check if the file exists
# if not os.path.exists(txt_path):
#     print("Error: The file does not exist. Please check the path and try again.")
# else:
#     # Define the output CSV file path
#     csv_path = 'test1' + ".csv"

#     # Process the text file
#     extracted_names = []
#     line_number = 0  # Track line numbers for debugging

#     with open(txt_path, 'r', encoding='utf-8') as txt_file:
#         for line in txt_file:
#             line_number += 1  # Increment line number
#             # Regex pattern to capture names with dots (.)
#             matches = re.findall(r'NPR\s{0,4}([A-Z][A-Z.\s]+)', line)

#             if matches:
#                 for match in matches:
#                     extracted_name = match.strip()
#                     extracted_names.append(extracted_name)
#                     print(f"✅ Extracted: '{extracted_name}' from Line {line_number}")  # Debugging print
#             else:
#                 # If no match found, add "NaN"
#                 extracted_names.append("NaN")
#                 print(f"⚠️ No NPR name found in Line {line_number}, replacing with 'NaN'.")

#     # # Create a DataFrame and save to CSV
#     # df = pd.DataFrame({'CCMS_NAME': extracted_names})
#     # df.to_csv(csv_path, index=False)

#     print(f"\n✅ Extraction complete. Found {len(df)} entries.")
#     print(f"✅ CSV created: {csv_path}")
# Out:
# Please enter the path to your space-separated .txt file: data\today.txt
# ✅ Extracted: 'ANKITA CHAUDHARY' from Line 1
# ✅ Extracted: 'ANITA ADHIKARI' from Line 2
# ✅ Extracted: 'RAMSHWORUP CHAUDHARY' from Line 3
# ✅ Extracted: 'SHAMKALA KHANAL' from Line 4
# ✅ Extracted: 'MANISHA SARKI' from Line 5
# ✅ Extracted: 'MAIT BAHADUR OLI' from Line 6
# ✅ Extracted: 'CHITRU P BHUSAL' from Line 7
# ✅ Extracted: 'SEMSARA BUDHA MAGAR' from Line 8
# ✅ Extracted: 'BINOD RAI' from Line 9
# ✅ Extracted: 'TIKARAM SUNAR' from Line 10
# ✅ Extracted: 'MIRA SHAH' from Line 11
# ✅ Extracted: 'SURESH KHADKA' from Line 12
# ✅ Extracted: 'ASHMITA RAWAL' from Line 13
# ✅ Extracted: 'PUSPA BIST' from Line 14
# ✅ Extracted: 'MAHESH BHATTA' from Line 15
# ✅ Extracted: 'SANTOSH CHAUDHARY' from Line 16
# ✅ Extracted: 'PRAKASH B ROKAYA' from Line 17
# ✅ Extracted: 'PAN SINGH DHAMI' from Line 18
# ✅ Extracted: 'CHANDRA K BOHARA' from Line 19
# ✅ Extracted: 'SITA KUMARI KSHEDAL' from Line 20
# ✅ Extracted: 'BHAGRATI BOHARA' from Line 21
# ✅ Extracted: 'SARITA KUMARI MANNI' from Line 22
# ✅ Extracted: 'GANGA KUMARI BOHARA' from Line 23
# ✅ Extracted: 'PARWATI MALLA' from Line 24
# ✅ Extracted: 'NAR BAHADUR BOHARA' from Line 25
# ✅ Extracted: 'SANDHYA SUBEDI' from Line 26
# ✅ Extracted: 'DEVIMAYA ADHIKARI' from Line 27
# ✅ Extracted: 'SAUGAT KRISHI TATHA' from Line 28
# ✅ Extracted: 'PUJA NEPALI PARIYAR' from Line 29
# ✅ Extracted: 'KISHOR JETHARA' from Line 30
# ✅ Extracted: 'SAPANA KUMARI SINGH' from Line 31
# ✅ Extracted: 'MAHADEV RAWAL' from Line 32
# ✅ Extracted: 'SURMA JOSHI' from Line 33
# ✅ Extracted: 'SABIN DAHAL' from Line 34
# ✅ Extracted: 'SALIK RAM GHIMIRE' from Line 35
# ✅ Extracted: 'SUSHMA P ADHIKARI' from Line 36
# ✅ Extracted: 'KHUMADEVI P BHATTRAI' from Line 37
# ✅ Extracted: 'NIBHA THAPA' from Line 38
# ✅ Extracted: 'BIR KUMARI GURUNG' from Line 39
# ✅ Extracted: 'MAYA DEVI DARJI' from Line 40
# ✅ Extracted: 'MANMAYA PURBACHHANE' from Line 41
# ✅ Extracted: 'PRIYA YADAV' from Line 42
# ✅ Extracted: 'SAKSHAM PALUNGWA' from Line 43
# ✅ Extracted: 'BISHNU B TAMANG' from Line 44
# ✅ Extracted: 'SUDIP SHIVABHAKTI' from Line 45
# ✅ Extracted: 'BIJAY TAMANG' from Line 46
# ✅ Extracted: 'ANMOL SUNUWAR' from Line 47
# ✅ Extracted: 'RADHA GYAWALI' from Line 48
# ✅ Extracted: 'SURAJ KHADGI' from Line 49
# ✅ Extracted: 'GYANU RAI' from Line 50
# ✅ Extracted: 'BIJAYA S MAGAR' from Line 51
# ✅ Extracted: 'RAJ KUMAR SHRESTHA' from Line 52
# ✅ Extracted: 'ANITA RAJBANSHI' from Line 53
# ✅ Extracted: 'GOPAL BUDHATHOKI' from Line 54
# ✅ Extracted: 'BHUWEN RAJBANSHI' from Line 55
# ✅ Extracted: 'RAMESH BHUJEL' from Line 56
# ✅ Extracted: 'GUNA RAJ NIRAULA' from Line 57
# ✅ Extracted: 'PREM CHHIRING LAMA' from Line 58
# ✅ Extracted: 'TEK MAYA GIRI' from Line 59
# ✅ Extracted: 'GANGA PD SIWAKOTI' from Line 60
# ✅ Extracted: 'SHIVA P KHATIWADA' from Line 61
# ✅ Extracted: 'GUNAHARI U DHUNGANA' from Line 62
# ✅ Extracted: 'TARA NIDHI ADHIKARI' from Line 63
# ✅ Extracted: 'MAHESH K KATHARIYA' from Line 64
# ✅ Extracted: 'SHANTA  GURUNG' from Line 65
# ✅ Extracted: 'ROMA THAPA' from Line 66
# ✅ Extracted: 'ASHMITA BARALI' from Line 67
# ✅ Extracted: 'SOBITA T GURUNG' from Line 68
# ✅ Extracted: 'DEEPTI PAUDEL' from Line 69
# ✅ Extracted: 'MANISHA BHATTARAI' from Line 70
# ✅ Extracted: 'CHUNU KUMARI TAMANG' from Line 71
# ✅ Extracted: 'RAJESH KUMAR YADAV' from Line 72
# ✅ Extracted: 'SARMITA SUNUWAR' from Line 73
# ✅ Extracted: 'ANISH BABU ARYAL' from Line 74
# ✅ Extracted: 'GRISHMA SHARMA' from Line 75
# ✅ Extracted: 'DEVRAJ THING' from Line 76
# ✅ Extracted: 'SAJINA BISTA' from Line 77
# ✅ Extracted: 'PRAKASH THAPA' from Line 78
# ✅ Extracted: 'DHIR BAHADUR GURUNG' from Line 79
# ✅ Extracted: 'BINDRA DURA' from Line 80
# ✅ Extracted: 'GAURI DHAMALA' from Line 81
# ✅ Extracted: 'SRIJANA BASTOLA' from Line 82
# ✅ Extracted: 'SUDIP THAPA' from Line 83
# ✅ Extracted: 'HUM MAYA GURUNG' from Line 84
# ✅ Extracted: 'DIPENDRA PUN MAGAR' from Line 85
# ✅ Extracted: 'LILA ADHIKARI' from Line 86
# ✅ Extracted: 'SUJATA KHAJA GHAR' from Line 87
# ✅ Extracted: 'RAJESH R CHHETRI' from Line 88
# ✅ Extracted: 'ARJUN MAJAKOTI' from Line 89
# ✅ Extracted: 'NARAYAN GIRI' from Line 90
# ✅ Extracted: 'KHAGENDRA DHAMI' from Line 91
# ✅ Extracted: 'MEG BAHADUR PANDEY' from Line 92
# ✅ Extracted: 'BHAGHO KEWAT' from Line 93
# ✅ Extracted: 'ARUNA THAPA' from Line 94
# ✅ Extracted: 'HASTA BHADHUR RAI' from Line 95
# ✅ Extracted: 'BIBEK RAI' from Line 96
# ✅ Extracted: 'UJWAL GHIMIRE' from Line 97
# ✅ Extracted: 'TANK PRASAD  POKHREL' from Line 98
# ✅ Extracted: 'ANISH BHATTARAI' from Line 99
# ✅ Extracted: 'SUNIL SHAH' from Line 100
# ✅ Extracted: 'RAMGOBIND  SAHA' from Line 101
# ✅ Extracted: 'GYANU P SAPKOTA' from Line 102
# ✅ Extracted: 'NARAYAN P UPADHYAYA' from Line 103
# ✅ Extracted: 'BHOJ RAJ POKHAREL' from Line 104
# ✅ Extracted: 'SHAHEENA PARWEEN' from Line 105
# ✅ Extracted: 'RUNI DEVI KAMAT' from Line 106
# ✅ Extracted: 'KHUSHBU K SONAR' from Line 107
# ✅ Extracted: 'DIKSHITA KATUWAL' from Line 108
# ✅ Extracted: 'URMILA KUMARI MEHTA' from Line 109
# ✅ Extracted: 'RAHUL SAH' from Line 110
# ✅ Extracted: 'JAICHAND K GUPTA' from Line 111
# ✅ Extracted: 'BRIJESH PANDEY' from Line 112
# ✅ Extracted: 'DEV KUMAR LAMA' from Line 113
# ✅ Extracted: 'RINKU KUMARI' from Line 114
# ✅ Extracted: 'MANULAL SAH TELI' from Line 115
# ✅ Extracted: 'LAL BABU P KURMI' from Line 116
# ✅ Extracted: 'INARDEV R HALKHOR' from Line 117
# ✅ Extracted: 'AMBIKA SHRESTHA' from Line 118
# ✅ Extracted: 'SHARDHA MESTARIN' from Line 119
# ✅ Extracted: 'DEV NARAYAN MAHATO' from Line 120
# ✅ Extracted: 'PATHRAIYA B MATSAY' from Line 121
# ✅ Extracted: 'SONALAL P CHAURASIYA' from Line 122
# ✅ Extracted: 'AAYUSHMAN P SEWA' from Line 123
# ✅ Extracted: 'TABASSUM BEGAM' from Line 124
# ✅ Extracted: 'MUNINDRA P YADAV' from Line 125
# ✅ Extracted: 'AJHAR MIYA HAJAM' from Line 126
# ✅ Extracted: 'NAVIN JHA' from Line 127
# ✅ Extracted: 'GYANI MAHATO' from Line 128
# ✅ Extracted: 'LAXMAN KUMAR SAH' from Line 129
# ✅ Extracted: 'SURENDRA SAHANI' from Line 130
# ✅ Extracted: 'NIRA SAUDEN LIMBU' from Line 131
# ✅ Extracted: 'KSHITIJ  KAFLEY' from Line 132
# ✅ Extracted: 'TIKA MAYA ACHARYA' from Line 133
# ✅ Extracted: 'SURESH DAHAL' from Line 134
# ✅ Extracted: 'DIPAK KHATIWADA' from Line 135
# ✅ Extracted: 'PUNAM KHATIWADA' from Line 136
# ✅ Extracted: 'ARATI N SHRESTHA' from Line 137
# ✅ Extracted: 'SWOSTIKA ACHARYA' from Line 138
# ✅ Extracted: 'YAGYARAJ THAPA' from Line 139
# ✅ Extracted: 'RIMA K. PRAJAPATI' from Line 140
# ✅ Extracted: 'SUNAYANA TARAMU' from Line 141
# ✅ Extracted: 'SHYAM B CHHANTYAL' from Line 142
# ✅ Extracted: 'YASHODHA K JOSHI' from Line 143
# ✅ Extracted: 'MANIKA  DANGAURA' from Line 144
# ✅ Extracted: 'ANKIT BAM' from Line 145
# ✅ Extracted: 'DHRUBA RAJ UPADHYAY' from Line 146
# ✅ Extracted: 'RIMA DHAMI' from Line 147
# ✅ Extracted: 'IRAK CHAUDHARY' from Line 148
# ✅ Extracted: 'PRAKASH B DHAMI' from Line 149
# ✅ Extracted: 'BHAGIMAN LIMBU' from Line 150
# ✅ Extracted: 'EKA BAHADUR RAI' from Line 151
# ✅ Extracted: 'SHYAM B SHRESTHA' from Line 152
# ✅ Extracted: 'SAMIR  NEPAL' from Line 153
# ✅ Extracted: 'RIM KUMAR LIMBU' from Line 154
# ✅ Extracted: 'SARASWATI TAMANG' from Line 155
# ✅ Extracted: 'NABIN ALEMAGAR' from Line 156
# ✅ Extracted: 'RAJENDRA SAHANI' from Line 157
# ✅ Extracted: 'MIN BAHADUR THING' from Line 158
# ✅ Extracted: 'AJAY JIMBA' from Line 159
# ✅ Extracted: 'TEJ KUMARI DHAMALA' from Line 160
# ✅ Extracted: 'KRISHNA P DAHAL' from Line 161
# ✅ Extracted: 'JIT BAHADUR GHALAN' from Line 162
# ✅ Extracted: 'LAL BAHADUR MOKTAN' from Line 163
# ✅ Extracted: 'SABINA OJHA' from Line 164
# ✅ Extracted: 'GHAMANDA B B.K.' from Line 165
# ✅ Extracted: 'APEKSHA GAIRE' from Line 166
# ✅ Extracted: 'UJJAWAL PANTHA' from Line 167
# ✅ Extracted: 'TARA DEVI RANA ALE' from Line 168
# ✅ Extracted: 'AGNIDHAR CHUWAI' from Line 169
# ✅ Extracted: 'BISHWO JIT MALLA' from Line 170
# ✅ Extracted: 'ANIL TRIPATHI' from Line 171
# ✅ Extracted: 'LAXMI A BHANDARI' from Line 172
# ✅ Extracted: 'SUSHILA SHRESTHA' from Line 173
# ✅ Extracted: 'DIYA SHRESTHA' from Line 174
# ✅ Extracted: 'GANGA RAI' from Line 175
# ✅ Extracted: 'SABINA PATHAK' from Line 176
# ✅ Extracted: 'KAMALESHWAR KATEL' from Line 177
# ✅ Extracted: 'PAMPHA KAMAR' from Line 178
# ✅ Extracted: 'SUMANA BHATTARAI' from Line 179
# ✅ Extracted: 'RADHIKA PUDASAINI' from Line 180
# ✅ Extracted: 'SUMAN TAMANG' from Line 181
# ✅ Extracted: 'BAIKUNTHA G.C.' from Line 182
# ✅ Extracted: 'SANJU RAI' from Line 183
# ✅ Extracted: 'BISHNU M SYANGTAN' from Line 184
# ✅ Extracted: 'ASALI JIMBA' from Line 185
# ✅ Extracted: 'SABINA LAMA' from Line 186
# ✅ Extracted: 'HEMLAL R MATAWALA' from Line 187
# ✅ Extracted: 'BAL BAHADUR KARKI' from Line 188
# ✅ Extracted: 'HIRA OLI' from Line 189
# ✅ Extracted: 'DHANANJAY TAMATA' from Line 190
# ✅ Extracted: 'PURNA KALA THAPA' from Line 191
# ✅ Extracted: 'SHER BAHADUR RAI' from Line 192
# ✅ Extracted: 'SANGE GURUNG' from Line 193
# ✅ Extracted: 'CHANDRA KALA RAI' from Line 194
# ✅ Extracted: 'UMA KHADGI' from Line 195
# ✅ Extracted: 'DEBRAJ SHRESTHA' from Line 196
# ✅ Extracted: 'SHIV SHRESTHA' from Line 197
# ✅ Extracted: 'SANAM RAI' from Line 198
# ✅ Extracted: 'BHIM BAHADUR AIR' from Line 199
# ✅ Extracted: 'BASANTA SINGH' from Line 200
# ✅ Extracted: 'DAMBAR B GURUNG' from Line 201
# ✅ Extracted: 'DIPA SHRESTHA' from Line 202
# ✅ Extracted: 'SHANKAR SHRESTHA' from Line 203
# ✅ Extracted: 'MAHISHA DHAMALA' from Line 204
# ✅ Extracted: 'GEGINDRA B BASNET' from Line 205
# ✅ Extracted: 'GANESH B THAPA' from Line 206
# ✅ Extracted: 'BHOJ KUMARI GAUTAM' from Line 207
# ✅ Extracted: 'BHUWAN KAFLE' from Line 208
# ✅ Extracted: 'TARA K ADHIKARI' from Line 209
# ✅ Extracted: 'JEEBAN K SHRESTHA' from Line 210
# ✅ Extracted: 'LIL B SHRESTHA' from Line 211
# ✅ Extracted: 'BHAGWATI B K' from Line 212
# ✅ Extracted: 'RITA  RAI' from Line 213
# ✅ Extracted: 'BIKASH KARKI' from Line 214
# ✅ Extracted: 'MUKESH NEPALI' from Line 215
# ✅ Extracted: 'KABIN SHERMA' from Line 216
# ✅ Extracted: 'DIPIKA RAI' from Line 217
# ✅ Extracted: 'BIMALA A SHANKHI' from Line 218
# ✅ Extracted: 'NIRA PARIYAR' from Line 219
# ✅ Extracted: 'SUSMITA THAPA' from Line 220
# ✅ Extracted: 'RAM BAHADUR ALE' from Line 221
# ✅ Extracted: 'NARENDRA SUNAR' from Line 222
# ✅ Extracted: 'ABINAS KASAI' from Line 223
# ✅ Extracted: 'GYAPCHAMAN TAMANG' from Line 224
# ✅ Extracted: 'BASANTA GURUNG' from Line 225
# ✅ Extracted: 'INDU KUMARI HARIJAN' from Line 226
# ✅ Extracted: 'KANHAI YADAV' from Line 227
# ✅ Extracted: 'OM PRAKASH KURMI' from Line 228
# ✅ Extracted: 'MEGHA KARN' from Line 229
# ✅ Extracted: 'NIRMALA DEVKOTA' from Line 230
# ✅ Extracted: 'LOK BDR BUDHATHOKI' from Line 231
# ✅ Extracted: 'LALIT KUMAR GUPTA' from Line 232
# ✅ Extracted: 'BINOD KUMAR SHAHI' from Line 233
# ✅ Extracted: 'DHYAN MURAU' from Line 234
# ✅ Extracted: 'ABDUL SALAM HALWAI' from Line 235
# ✅ Extracted: 'SHOBHA SHAH' from Line 236
# ✅ Extracted: 'DIPENDRA S THAKURI' from Line 237
# ✅ Extracted: 'KALAMUDDIN RAI' from Line 238
# ✅ Extracted: 'PRAKASH GAUTAM' from Line 239
# ✅ Extracted: 'SHOBHA CHAUDHARY' from Line 240
# ✅ Extracted: 'BHAWANI P NEUPANE' from Line 241
# ✅ Extracted: 'HAJRAT ALI SAE' from Line 242
# ✅ Extracted: 'SHANTI CHAUDHARY' from Line 243
# ✅ Extracted: 'BISHNU THAPA' from Line 244
# ✅ Extracted: 'KAMAL RAJ JAISHI' from Line 245
# ✅ Extracted: 'RAJANI D CHAUDHARY' from Line 246
# ✅ Extracted: 'DHARMENDRA AIDEE' from Line 247
# ✅ Extracted: 'RUPA TAMATTA' from Line 248
# ✅ Extracted: 'SHER BAHADUR SINGH' from Line 249
# ✅ Extracted: 'BHAWANA AWASTHI' from Line 250
# ✅ Extracted: 'SONURAM CHAUDHARY' from Line 251
# ✅ Extracted: 'DIPAK BAHADUR SINGH' from Line 252
# ✅ Extracted: 'YOGESH JORA' from Line 253
# ✅ Extracted: 'MANGITLA M LIMBU' from Line 254
# ✅ Extracted: 'PHUNGITLA M LIMBU' from Line 255
# ✅ Extracted: 'SHIKHA KAFLE' from Line 256
# ✅ Extracted: 'SHUSMA KEDEM' from Line 257
# ✅ Extracted: 'PRAMILA POKHAREL' from Line 258
# ✅ Extracted: 'SHREE MAYA GURUNG' from Line 259
# ✅ Extracted: 'KAMALA LIMBU' from Line 260
# ✅ Extracted: 'SMRITI RAI' from Line 261
# ✅ Extracted: 'SHASIKA RAI' from Line 262
# ✅ Extracted: 'SABITRI  LIMBU' from Line 263
# ✅ Extracted: 'BINA RAI' from Line 264
# ✅ Extracted: 'MAYA DEBI TAMANG' from Line 265
# ✅ Extracted: 'KAMALA RAI' from Line 266
# ✅ Extracted: 'NARENDRA YAKHA' from Line 267
# ✅ Extracted: 'SUNNY PRADHAN' from Line 268
# ✅ Extracted: 'SHIVA KUMAR YOGI' from Line 269
# ✅ Extracted: 'ASHA RAI' from Line 270
# ✅ Extracted: 'TULASA K POKHREL' from Line 271
# ✅ Extracted: 'RAM CHANDRA RAI' from Line 272
# ✅ Extracted: 'ESMARY SUBBA LIMBU' from Line 273
# ✅ Extracted: 'SHREEPARSAD LIMBU' from Line 274
# ✅ Extracted: 'SUMAN PANDIT' from Line 275
# ✅ Extracted: 'PRAKRITI TIWARI' from Line 276
# ✅ Extracted: 'PRAMOD REGMI' from Line 277
# ✅ Extracted: 'NAWARAJ REGMI' from Line 278
# ✅ Extracted: 'BISNU NEPALI' from Line 279
# ✅ Extracted: 'PRAKASH JAISI' from Line 280
# ✅ Extracted: 'RAMCHANDRA JAISI' from Line 281
# ✅ Extracted: 'CHANDRA B KHADKA' from Line 282
# ✅ Extracted: 'KRITILAL JAISI' from Line 283
# ✅ Extracted: 'SUNITA BOHARA SINGH' from Line 284
# ✅ Extracted: 'SRISHTI SHAHI SINGH' from Line 285
# ✅ Extracted: 'DHAN BAHADUR SINGH' from Line 286
# ✅ Extracted: 'KHADKA B CHALAUNE' from Line 287
# ✅ Extracted: 'DEUSARA JAISI' from Line 288
# ✅ Extracted: 'KARNA B KHADKA' from Line 289
# ✅ Extracted: 'KRISHNA P JAISI' from Line 290
# ✅ Extracted: 'BISHNU SHAHI' from Line 291
# ✅ Extracted: 'BHIM BAHADUR TIRUWA' from Line 292
# ✅ Extracted: 'BIPANA NEPALI' from Line 293
# ✅ Extracted: 'CHAKRA B SINGH' from Line 294
# ✅ Extracted: 'SHARADA A BASNET' from Line 295
# ✅ Extracted: 'NIM BAHADUR DAMAI' from Line 296
# ✅ Extracted: 'BHARAT B SINGH' from Line 297
# ✅ Extracted: 'BIRENDRA B SIGHN' from Line 298
# ✅ Extracted: 'JANAK BAHADUR THAPA' from Line 299
# ✅ Extracted: 'MINIKA SHAHI SINGH' from Line 300
# ✅ Extracted: 'SITA KUMARI ROKAYA' from Line 301
# ✅ Extracted: 'KARNA JUNG SHAH' from Line 302
# ✅ Extracted: 'PREM BAHADUR SHAHI' from Line 303
# ✅ Extracted: 'AMALA . SHAHI' from Line 304
# ✅ Extracted: 'BISHNU JAISI' from Line 305
# ✅ Extracted: 'RAMESH KUMAR BASNET' from Line 306
# ✅ Extracted: 'KALIKA SHAHI' from Line 307
# ✅ Extracted: 'MAN BAHADUR SINGH' from Line 308
# ✅ Extracted: 'HARI SHARAN LAMSAL' from Line 309
# ✅ Extracted: 'KIRAN KHADKA' from Line 310
# ✅ Extracted: 'UMESH KUMAR THAPA' from Line 311
# ✅ Extracted: 'SHALIK RAM PARAJULI' from Line 312
# ✅ Extracted: 'KISHAN A KRISHI' from Line 313
# ✅ Extracted: 'SITA NEGI' from Line 314
# ✅ Extracted: 'PUJA DAMAI' from Line 315
# ✅ Extracted: 'BEBINA THAPA MAGAR' from Line 316
# ✅ Extracted: 'SONIYA CHAND' from Line 317
# ✅ Extracted: 'HIMANI SUNAR TIRUWA' from Line 318
# ✅ Extracted: 'KARESHMA KARKI' from Line 319
# ✅ Extracted: 'PRINKA KHADKA' from Line 320
# ✅ Extracted: 'KARUNAKAR BHATTA' from Line 321
# ✅ Extracted: 'BINDU KUMARI SAUD' from Line 322
# ✅ Extracted: 'RAJESH  SUNAR' from Line 323
# ✅ Extracted: 'SABITA SHAHI' from Line 324
# ✅ Extracted: 'USHA SUNAR' from Line 325
# ✅ Extracted: 'PRAMILA KU BHAT' from Line 326
# ✅ Extracted: 'BHAWANA JAIRUP' from Line 327
# ✅ Extracted: 'BISHAL THAPA MAGAR' from Line 328
# ✅ Extracted: 'GANESH B KHATRI' from Line 329
# ✅ Extracted: 'HIMANI GIRI' from Line 330
# ✅ Extracted: 'BADRI DAMAI' from Line 331
# ✅ Extracted: 'BUDDHA LAXMI  BAIJU' from Line 332
# ✅ Extracted: 'CHAMPAK  SUBEDI' from Line 333
# ✅ Extracted: 'RABIN JOSHI' from Line 334
# ✅ Extracted: 'SATYA RAM BASUKALA' from Line 335
# ✅ Extracted: 'LAXMI SUNDAR  SUWAL' from Line 336
# ✅ Extracted: 'SUNTALI LAMICHHANE' from Line 337
# ✅ Extracted: 'BHIM BAHADUR BATA' from Line 338
# ✅ Extracted: 'SURESH PD.  NEUPANE' from Line 339
# ✅ Extracted: 'GANESH MAN  KOJU' from Line 340
# ✅ Extracted: 'RAM C BHUJU' from Line 341
# ✅ Extracted: 'NARAYAN KUMAR MAJHI' from Line 342
# ✅ Extracted: 'SARITA CHAUDHARY' from Line 343
# ✅ Extracted: 'TANUJA CHAUDHARY' from Line 344
# ✅ Extracted: 'GITA KUMARI SAH' from Line 345
# ✅ Extracted: 'RAM BILASH MANDAL' from Line 346
# ✅ Extracted: 'GANGA KUMARI YOGI' from Line 347
# ✅ Extracted: 'BISHNA B SHAHI' from Line 348
# ✅ Extracted: 'GANGA KUMARI KHATRI' from Line 349
# ✅ Extracted: 'GYANENDRA B SHRESTHA' from Line 350
# ✅ Extracted: 'BIMALA RANA' from Line 351
# ✅ Extracted: 'PURNIMA PUN BUDHA' from Line 352
# ✅ Extracted: 'PRADIP BUDHA MAGAR' from Line 353
# ✅ Extracted: 'SARAHANA S THAKURI' from Line 354
# ✅ Extracted: 'KSHETRA B KATUWAL' from Line 355
# ✅ Extracted: 'NABIN KARKI' from Line 356
# ✅ Extracted: 'APAR KARKI' from Line 357
# ✅ Extracted: 'GYANENDRA B RAI' from Line 358
# ✅ Extracted: 'MADAN KUMAR MAGAR' from Line 359
# ✅ Extracted: 'SHARAD G STORE' from Line 360
# ✅ Extracted: 'SHOVA B BHANDARI' from Line 361
# ✅ Extracted: 'PABITRA SOMAI' from Line 362
# ✅ Extracted: 'ABHINAB KHANAL' from Line 363
# ✅ Extracted: 'RITA SHRESTHA' from Line 364
# ✅ Extracted: 'ISHWOR THUYA' from Line 365
# ✅ Extracted: 'UNISHA GAINJU' from Line 366
# ✅ Extracted: 'MAIYA SHRESTHA' from Line 367
# ✅ Extracted: 'DHIRENDRA K SINGH' from Line 368
# ✅ Extracted: 'KABITA PANDEY' from Line 369
# ✅ Extracted: 'BIRBAHADUR SAH' from Line 370
# ✅ Extracted: 'MADHURI KUMARI' from Line 371
# ✅ Extracted: 'KHIMA K C' from Line 372
# ✅ Extracted: 'BHIM KUMARI K' from Line 373
# ✅ Extracted: 'LAXMI MALLA' from Line 374
# ✅ Extracted: 'BINOD SHAHA' from Line 375
# ✅ Extracted: 'ANJANA GHARTI' from Line 376
# ✅ Extracted: 'SUNITA OLI' from Line 377
# ✅ Extracted: 'DEV BAHADUR BATHA' from Line 378
# ✅ Extracted: 'SHOVA RAM SUNAR' from Line 379
# ✅ Extracted: 'SHANKAR PACHHAI' from Line 380
# ✅ Extracted: 'RAM MAYA PATHAK' from Line 381
# ✅ Extracted: 'LAXMI OLI' from Line 382
# ✅ Extracted: 'PUJA BEAUTY PALOUR' from Line 383
# ✅ Extracted: 'SANAD NIRMAN SEWA' from Line 384
# ✅ Extracted: 'BINITA ACHHAMI' from Line 385
# ✅ Extracted: 'UDAY SINGH THAKURI' from Line 386
# ✅ Extracted: 'MINA K BHANDARI' from Line 387
# ✅ Extracted: 'SUDIP D.J. TENT' from Line 388
# ✅ Extracted: 'RAMGOPAL GODIYA' from Line 389
# ✅ Extracted: 'SHARMILA THAPA' from Line 390
# ✅ Extracted: 'JENISH SHRESTHA' from Line 391
# ✅ Extracted: 'DURGA MAN LAMA' from Line 392
# ✅ Extracted: 'NAND KUMARI MAHATO' from Line 393
# ✅ Extracted: 'SOM BAHADUR HAYU' from Line 394
# ✅ Extracted: 'APSON P TAMANG' from Line 395
# ✅ Extracted: 'SUBHAS SUNAR' from Line 396
# ✅ Extracted: 'BISNU MAYA REGMI' from Line 397
# ✅ Extracted: 'KANCHAN THAPA' from Line 398
# ✅ Extracted: 'BISHNU MAYA PARIYAR' from Line 399
# ✅ Extracted: 'MANISH ADHIKARI' from Line 400
# ✅ Extracted: 'BIKESH KUMAR SHAH' from Line 401
# ✅ Extracted: 'MUMTAJ ALAM' from Line 402
# ✅ Extracted: 'RAMESH K CHAUDHARY' from Line 403
# ✅ Extracted: 'PRAKASH THAPA MAGAR' from Line 404
# ✅ Extracted: 'TARA NATH CHAUDHARY' from Line 405
# ✅ Extracted: 'BIHANI RAYA KSHETRI' from Line 406
# ✅ Extracted: 'UPENDRA P YADAV' from Line 407
# ✅ Extracted: 'ROJINA CHAULAGAIN' from Line 408
# ✅ Extracted: 'SUK LAL PAKHRIN' from Line 409
# ✅ Extracted: 'MOHAN KUAMR GAUTAM' from Line 410
# ✅ Extracted: 'SUNITA GHALAN' from Line 411
# ✅ Extracted: 'SONI LAMA GHALAN' from Line 412
# ✅ Extracted: 'PUJA WAIBA' from Line 413
# ✅ Extracted: 'MANILA GHALAN' from Line 414
# ✅ Extracted: 'PRITIKA PRADHAN' from Line 415
# ✅ Extracted: 'SAGUN BHATTARAI' from Line 416
# ✅ Extracted: 'NABINA KHADKA' from Line 417
# ✅ Extracted: 'SUKURAM LOPCHAN' from Line 418
# ✅ Extracted: 'MANOJ KUMAR SAH' from Line 419
# ✅ Extracted: 'ARUNA GOLE' from Line 420
# ✅ Extracted: 'HARISHARAN NEUPANE' from Line 421
# ✅ Extracted: 'RACHANA THOKAR' from Line 422
# ✅ Extracted: 'RAM BAHADUR  KUMALE' from Line 423
# ✅ Extracted: 'DIPAK SHRESTHA' from Line 424
# ✅ Extracted: 'PRAMILA MUKTAN' from Line 425
# ✅ Extracted: 'SUSMITA BOHORA' from Line 426
# ✅ Extracted: 'RANJANA K TAMANG' from Line 427
# ✅ Extracted: 'KUMARI TITUNG' from Line 428
# ✅ Extracted: 'SHASHI KUMAR YADAV' from Line 429
# ✅ Extracted: 'MANMAYA MUKTAN' from Line 430
# ✅ Extracted: 'SUBASH PATHAK' from Line 431
# ✅ Extracted: 'JIT BAHADUR RUMBA' from Line 432
# ✅ Extracted: 'TEKAR P GHIMIRE' from Line 433
# ✅ Extracted: 'RABIKUMAR SHRESTHA' from Line 434
# ✅ Extracted: 'KRISHNA MAYA NEUPANE' from Line 435
# ✅ Extracted: 'PRAKRITI GAUTAM' from Line 436
# ✅ Extracted: 'AAKRITI MUKTAN' from Line 437
# ✅ Extracted: 'KAMALA RUMBA' from Line 438
# ✅ Extracted: 'BINISHA MISHRA' from Line 439
# ✅ Extracted: 'KARUNA GOLE' from Line 440
# ✅ Extracted: 'SUNIL RUMBA' from Line 441
# ✅ Extracted: 'ASMITA BHATTARAI' from Line 442
# ✅ Extracted: 'CHITRA B THAPA' from Line 443
# ✅ Extracted: 'NILAM MASKEY' from Line 444
# ✅ Extracted: 'AAISOR NAU' from Line 445
# ✅ Extracted: 'SANGITA SUNAR' from Line 446
# ✅ Extracted: 'GITA THAPA' from Line 447
# ✅ Extracted: 'SAMJHANA THAPA' from Line 448
# ✅ Extracted: 'SARITA SAPKOTA' from Line 449
# ✅ Extracted: 'KAMANA BHATTARAI' from Line 450
# ✅ Extracted: 'NUMAKALA NEPALI' from Line 451
# ✅ Extracted: 'SANGITA KAFLE' from Line 452
# ✅ Extracted: 'REJINA SUNAR' from Line 453
# ✅ Extracted: 'PRITHVI RANA MAGAR' from Line 454
# ✅ Extracted: 'LISA THAPA' from Line 455
# ✅ Extracted: 'NARAYAN P ACHARYA' from Line 456
# ✅ Extracted: 'BHUPRAJ BASNET' from Line 457
# ✅ Extracted: 'RONIKA  KOIRALA' from Line 458
# ✅ Extracted: 'GUNARAJ POKHREL' from Line 459
# ✅ Extracted: 'LALITA CHAUDHARY' from Line 460
# ✅ Extracted: 'JITENDRA RAI' from Line 461
# ✅ Extracted: 'MAHENDRA TAMANG' from Line 462
# ✅ Extracted: 'BABU RAM DAHAL' from Line 463
# ✅ Extracted: 'TILAK B KHATRI' from Line 464
# ✅ Extracted: 'ANAMIKA SINGH' from Line 465
# ✅ Extracted: 'JANUKA GAUTAM' from Line 466
# ✅ Extracted: 'RINA B PAKHARIN' from Line 467
# ✅ Extracted: 'CHINA SAPKOTA' from Line 468
# ✅ Extracted: 'BIPLAV  NEUPANE' from Line 469
# ✅ Extracted: 'AMAR BAHADUR  SHRESTHA' from Line 470
# ✅ Extracted: 'AMULA KUMARI YADHAV' from Line 471
# ✅ Extracted: 'MANISH SAPKOTA' from Line 472
# ✅ Extracted: 'SAMJHANA KHANAL' from Line 473
# ✅ Extracted: 'AMAR LAMA' from Line 474
# ✅ Extracted: 'HEM KUMAR KARKI' from Line 475
# ✅ Extracted: 'UMESH KUMAR SHARMA  PARAJ' from Line 476
# ✅ Extracted: 'ARJUN RAI' from Line 477
# ✅ Extracted: 'LISANU THARU' from Line 478
# ✅ Extracted: 'NETRA B NEPALI' from Line 479
# ✅ Extracted: 'MUKUND JOSHI' from Line 480
# ✅ Extracted: 'HIKMAT BAHADUR SAUD' from Line 481
# ✅ Extracted: 'NARAYAN KUMAR  REGMI' from Line 482
# ✅ Extracted: 'SURESH NEGI' from Line 483
# ✅ Extracted: 'SURAJ  SHARMA' from Line 484
# ✅ Extracted: 'DIPIKA KUNWAR' from Line 485
# ✅ Extracted: 'PRABESH MARASINI' from Line 486
# ✅ Extracted: 'BIJAYA BASYAL' from Line 487
# ✅ Extracted: 'GIRDHARI P CHAUDHARY' from Line 488
# ✅ Extracted: 'KUMAR TIMILSENA' from Line 489
# ✅ Extracted: 'GOBINDA THAPA' from Line 490
# ✅ Extracted: 'NARESH KUMAR  SAH' from Line 491
# ✅ Extracted: 'RAMESH BUDHADHOKI' from Line 492
# ✅ Extracted: 'CHAMELI REGMI' from Line 493
# ✅ Extracted: 'HEMRAJ RAI' from Line 494
# ✅ Extracted: 'DINESH NEPALI' from Line 495
# ✅ Extracted: 'SITA BISHOWKARMA' from Line 496
# ✅ Extracted: 'AASHA K. THAKUR' from Line 497
# ✅ Extracted: 'YUBRAJ GYAWALI' from Line 498
# ✅ Extracted: 'SHIVPRASAD CHAUDHARY' from Line 499
# ✅ Extracted: 'BUDDHA BHANDARI' from Line 500
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 35
#      29             print(f"⚠️ No NPR name found in Line {line_number}, replacing with 'NaN'.")
#      31 # # Create a DataFrame and save to CSV
#      32 # df = pd.DataFrame({'CCMS_NAME': extracted_names})
#      33 # df.to_csv(csv_path, index=False)
# ---> 35 print(f"\n✅ Extraction complete. Found {len(df)} entries.")
#      36 print(f"✅ CSV created: {csv_path}")
#
# NameError: name 'df' is not defined

# %%
# for multiple txt at a glance 

import os
import re
import pandas as pd

# Ask user if they have multiple text files
multiple_files = input("Do you have multiple text files to process? (yes/no): ").lower().strip()

all_extracted_names = []
line_number = 0

if multiple_files == 'yes':
    # Ask for multiple file paths
    txt_paths = []
    while True:
        path = input("Please enter the path to a space-separated .txt file (or 'done' to finish): ")
        if path.lower() == 'done':
            break
        if os.path.exists(path):
            txt_paths.append(path)
        else:
            print("Error: The file does not exist. Please check the path and try again.")

    if not txt_paths:
        print("Error: No valid files provided. Exiting.")
    else:
        # Process each text file
        for txt_path in txt_paths:
            with open(txt_path, 'r', encoding='utf-8') as txt_file:
                for line in txt_file:
                    line_number += 1
                    # Regex pattern to capture names with dots (.)
                    matches = re.findall(r'NPR\s{0,4}([A-Z][A-Z.\s]+)', line)

                    if matches:
                        for match in matches:
                            extracted_name = match.strip()
                            all_extracted_names.append(extracted_name)
                            print(f"✅ Extracted: '{extracted_name}' from Line {line_number} in {txt_path}")
                    else:
                        all_extracted_names.append("NaN")
                        print(f"⚠️ No NPR name found in Line {line_number} in {txt_path}, replacing with 'NaN'.")

        # Create a DataFrame and save to CSV
        df = pd.DataFrame({'CCMS_NAME': all_extracted_names})
        csv_path = 'combined_output.csv'
        df.to_csv(csv_path, index=False)

        print(f"\n✅ Extraction complete. Found {len(df)} entries from {len(txt_paths)} files.")
        print(f"✅ CSV created: {csv_path}")

else:
    # Original single file processing
    txt_path = input("Please enter the path to your space-separated .txt file: ")

    # Check if the file exists
    if not os.path.exists(txt_path):
        print("Error: The file does not exist. Please check the path and try again.")
    else:
        # Define the output CSV file path
        csv_path = 'test1.csv'

        # Process the text file
        extracted_names = []
        line_number = 0

        with open(txt_path, 'r', encoding='utf-8') as txt_file:
            for line in txt_file:
                line_number += 1
                # Regex pattern to capture names with dots (.)
                matches = re.findall(r'NPR\s{0,4}([A-Z][A-Z.\s]+)', line)

                if matches:
                    for match in matches:
                        extracted_name = match.strip()
                        extracted_names.append(extracted_name)
                        print(f"✅ Extracted: '{extracted_name}' from Line {line_number}")
                else:
                    extracted_names.append("NaN")
                    print(f"⚠️ No NPR name found in Line {line_number}, replacing with 'NaN'.")

        # Create a DataFrame and save to CSV
        df = pd.DataFrame({'CCMS_NAME': extracted_names})
        df.to_csv(csv_path, index=False)

        print(f"\n✅ Extraction complete. Found {len(df)} entries.")
        print(f"✅ CSV created: {csv_path}")
        print(f"Details of Names{DataFrame.describe()}")
# Out:
# Do you have multiple text files to process? (yes/no): yes
# Please enter the path to a space-separated .txt file (or 'done' to finish): data\today.txt
# Please enter the path to a space-separated .txt file (or 'done' to finish): data\today1.txt
# Please enter the path to a space-separated .txt file (or 'done' to finish): data\today2.txt
# Please enter the path to a space-separated .txt file (or 'done' to finish): data\today3.txt
# Please enter the path to a space-separated .txt file (or 'done' to finish): done
# ✅ Extracted: 'ANKITA CHAUDHARY' from Line 1 in data\today.txt
# ✅ Extracted: 'ANITA ADHIKARI' from Line 2 in data\today.txt
# ✅ Extracted: 'RAMSHWORUP CHAUDHARY' from Line 3 in data\today.txt
# ✅ Extracted: 'SHAMKALA KHANAL' from Line 4 in data\today.txt
# ✅ Extracted: 'MANISHA SARKI' from Line 5 in data\today.txt
# ✅ Extracted: 'MAIT BAHADUR OLI' from Line 6 in data\today.txt
# ✅ Extracted: 'CHITRU P BHUSAL' from Line 7 in data\today.txt
# ✅ Extracted: 'SEMSARA BUDHA MAGAR' from Line 8 in data\today.txt
# ✅ Extracted: 'BINOD RAI' from Line 9 in data\today.txt
# ✅ Extracted: 'TIKARAM SUNAR' from Line 10 in data\today.txt
# ✅ Extracted: 'MIRA SHAH' from Line 11 in data\today.txt
# ✅ Extracted: 'SURESH KHADKA' from Line 12 in data\today.txt
# ✅ Extracted: 'ASHMITA RAWAL' from Line 13 in data\today.txt
# ✅ Extracted: 'PUSPA BIST' from Line 14 in data\today.txt
# ✅ Extracted: 'MAHESH BHATTA' from Line 15 in data\today.txt
# ✅ Extracted: 'SANTOSH CHAUDHARY' from Line 16 in data\today.txt
# ✅ Extracted: 'PRAKASH B ROKAYA' from Line 17 in data\today.txt
# ✅ Extracted: 'PAN SINGH DHAMI' from Line 18 in data\today.txt
# ✅ Extracted: 'CHANDRA K BOHARA' from Line 19 in data\today.txt
# ✅ Extracted: 'SITA KUMARI KSHEDAL' from Line 20 in data\today.txt
# ✅ Extracted: 'BHAGRATI BOHARA' from Line 21 in data\today.txt
# ✅ Extracted: 'SARITA KUMARI MANNI' from Line 22 in data\today.txt
# ✅ Extracted: 'GANGA KUMARI BOHARA' from Line 23 in data\today.txt
# ✅ Extracted: 'PARWATI MALLA' from Line 24 in data\today.txt
# ✅ Extracted: 'NAR BAHADUR BOHARA' from Line 25 in data\today.txt
# ✅ Extracted: 'SANDHYA SUBEDI' from Line 26 in data\today.txt
# ✅ Extracted: 'DEVIMAYA ADHIKARI' from Line 27 in data\today.txt
# ✅ Extracted: 'SAUGAT KRISHI TATHA' from Line 28 in data\today.txt
# ✅ Extracted: 'PUJA NEPALI PARIYAR' from Line 29 in data\today.txt
# ✅ Extracted: 'KISHOR JETHARA' from Line 30 in data\today.txt
# ✅ Extracted: 'SAPANA KUMARI SINGH' from Line 31 in data\today.txt
# ✅ Extracted: 'MAHADEV RAWAL' from Line 32 in data\today.txt
# ✅ Extracted: 'SURMA JOSHI' from Line 33 in data\today.txt
# ✅ Extracted: 'SABIN DAHAL' from Line 34 in data\today.txt
# ✅ Extracted: 'SALIK RAM GHIMIRE' from Line 35 in data\today.txt
# ✅ Extracted: 'SUSHMA P ADHIKARI' from Line 36 in data\today.txt
# ✅ Extracted: 'KHUMADEVI P BHATTRAI' from Line 37 in data\today.txt
# ✅ Extracted: 'NIBHA THAPA' from Line 38 in data\today.txt
# ✅ Extracted: 'BIR KUMARI GURUNG' from Line 39 in data\today.txt
# ✅ Extracted: 'MAYA DEVI DARJI' from Line 40 in data\today.txt
# ✅ Extracted: 'MANMAYA PURBACHHANE' from Line 41 in data\today.txt
# ✅ Extracted: 'PRIYA YADAV' from Line 42 in data\today.txt
# ✅ Extracted: 'SAKSHAM PALUNGWA' from Line 43 in data\today.txt
# ✅ Extracted: 'BISHNU B TAMANG' from Line 44 in data\today.txt
# ✅ Extracted: 'SUDIP SHIVABHAKTI' from Line 45 in data\today.txt
# ✅ Extracted: 'BIJAY TAMANG' from Line 46 in data\today.txt
# ✅ Extracted: 'ANMOL SUNUWAR' from Line 47 in data\today.txt
# ✅ Extracted: 'RADHA GYAWALI' from Line 48 in data\today.txt
# ✅ Extracted: 'SURAJ KHADGI' from Line 49 in data\today.txt
# ✅ Extracted: 'GYANU RAI' from Line 50 in data\today.txt
# ✅ Extracted: 'BIJAYA S MAGAR' from Line 51 in data\today.txt
# ✅ Extracted: 'RAJ KUMAR SHRESTHA' from Line 52 in data\today.txt
# ✅ Extracted: 'ANITA RAJBANSHI' from Line 53 in data\today.txt
# ✅ Extracted: 'GOPAL BUDHATHOKI' from Line 54 in data\today.txt
# ✅ Extracted: 'BHUWEN RAJBANSHI' from Line 55 in data\today.txt
# ✅ Extracted: 'RAMESH BHUJEL' from Line 56 in data\today.txt
# ✅ Extracted: 'GUNA RAJ NIRAULA' from Line 57 in data\today.txt
# ✅ Extracted: 'PREM CHHIRING LAMA' from Line 58 in data\today.txt
# ✅ Extracted: 'TEK MAYA GIRI' from Line 59 in data\today.txt
# ✅ Extracted: 'GANGA PD SIWAKOTI' from Line 60 in data\today.txt
# ✅ Extracted: 'SHIVA P KHATIWADA' from Line 61 in data\today.txt
# ✅ Extracted: 'GUNAHARI U DHUNGANA' from Line 62 in data\today.txt
# ✅ Extracted: 'TARA NIDHI ADHIKARI' from Line 63 in data\today.txt
# ✅ Extracted: 'MAHESH K KATHARIYA' from Line 64 in data\today.txt
# ✅ Extracted: 'SHANTA  GURUNG' from Line 65 in data\today.txt
# ✅ Extracted: 'ROMA THAPA' from Line 66 in data\today.txt
# ✅ Extracted: 'ASHMITA BARALI' from Line 67 in data\today.txt
# ✅ Extracted: 'SOBITA T GURUNG' from Line 68 in data\today.txt
# ✅ Extracted: 'DEEPTI PAUDEL' from Line 69 in data\today.txt
# ✅ Extracted: 'MANISHA BHATTARAI' from Line 70 in data\today.txt
# ✅ Extracted: 'CHUNU KUMARI TAMANG' from Line 71 in data\today.txt
# ✅ Extracted: 'RAJESH KUMAR YADAV' from Line 72 in data\today.txt
# ✅ Extracted: 'SARMITA SUNUWAR' from Line 73 in data\today.txt
# ✅ Extracted: 'ANISH BABU ARYAL' from Line 74 in data\today.txt
# ✅ Extracted: 'GRISHMA SHARMA' from Line 75 in data\today.txt
# ✅ Extracted: 'DEVRAJ THING' from Line 76 in data\today.txt
# ✅ Extracted: 'SAJINA BISTA' from Line 77 in data\today.txt
# ✅ Extracted: 'PRAKASH THAPA' from Line 78 in data\today.txt
# ✅ Extracted: 'DHIR BAHADUR GURUNG' from Line 79 in data\today.txt
# ✅ Extracted: 'BINDRA DURA' from Line 80 in data\today.txt
# ✅ Extracted: 'GAURI DHAMALA' from Line 81 in data\today.txt
# ✅ Extracted: 'SRIJANA BASTOLA' from Line 82 in data\today.txt
# ✅ Extracted: 'SUDIP THAPA' from Line 83 in data\today.txt
# ✅ Extracted: 'HUM MAYA GURUNG' from Line 84 in data\today.txt
# ✅ Extracted: 'DIPENDRA PUN MAGAR' from Line 85 in data\today.txt
# ✅ Extracted: 'LILA ADHIKARI' from Line 86 in data\today.txt
# ✅ Extracted: 'SUJATA KHAJA GHAR' from Line 87 in data\today.txt
# ✅ Extracted: 'RAJESH R CHHETRI' from Line 88 in data\today.txt
# ✅ Extracted: 'ARJUN MAJAKOTI' from Line 89 in data\today.txt
# ✅ Extracted: 'NARAYAN GIRI' from Line 90 in data\today.txt
# ✅ Extracted: 'KHAGENDRA DHAMI' from Line 91 in data\today.txt
# ✅ Extracted: 'MEG BAHADUR PANDEY' from Line 92 in data\today.txt
# ✅ Extracted: 'BHAGHO KEWAT' from Line 93 in data\today.txt
# ✅ Extracted: 'ARUNA THAPA' from Line 94 in data\today.txt
# ✅ Extracted: 'HASTA BHADHUR RAI' from Line 95 in data\today.txt
# ✅ Extracted: 'BIBEK RAI' from Line 96 in data\today.txt
# ✅ Extracted: 'UJWAL GHIMIRE' from Line 97 in data\today.txt
# ✅ Extracted: 'TANK PRASAD  POKHREL' from Line 98 in data\today.txt
# ✅ Extracted: 'ANISH BHATTARAI' from Line 99 in data\today.txt
# ✅ Extracted: 'SUNIL SHAH' from Line 100 in data\today.txt
# ✅ Extracted: 'RAMGOBIND  SAHA' from Line 101 in data\today.txt
# ✅ Extracted: 'GYANU P SAPKOTA' from Line 102 in data\today.txt
# ✅ Extracted: 'NARAYAN P UPADHYAYA' from Line 103 in data\today.txt
# ✅ Extracted: 'BHOJ RAJ POKHAREL' from Line 104 in data\today.txt
# ✅ Extracted: 'SHAHEENA PARWEEN' from Line 105 in data\today.txt
# ✅ Extracted: 'RUNI DEVI KAMAT' from Line 106 in data\today.txt
# ✅ Extracted: 'KHUSHBU K SONAR' from Line 107 in data\today.txt
# ✅ Extracted: 'DIKSHITA KATUWAL' from Line 108 in data\today.txt
# ✅ Extracted: 'URMILA KUMARI MEHTA' from Line 109 in data\today.txt
# ✅ Extracted: 'RAHUL SAH' from Line 110 in data\today.txt
# ✅ Extracted: 'JAICHAND K GUPTA' from Line 111 in data\today.txt
# ✅ Extracted: 'BRIJESH PANDEY' from Line 112 in data\today.txt
# ✅ Extracted: 'DEV KUMAR LAMA' from Line 113 in data\today.txt
# ✅ Extracted: 'RINKU KUMARI' from Line 114 in data\today.txt
# ✅ Extracted: 'MANULAL SAH TELI' from Line 115 in data\today.txt
# ✅ Extracted: 'LAL BABU P KURMI' from Line 116 in data\today.txt
# ✅ Extracted: 'INARDEV R HALKHOR' from Line 117 in data\today.txt
# ✅ Extracted: 'AMBIKA SHRESTHA' from Line 118 in data\today.txt
# ✅ Extracted: 'SHARDHA MESTARIN' from Line 119 in data\today.txt
# ✅ Extracted: 'DEV NARAYAN MAHATO' from Line 120 in data\today.txt
# ✅ Extracted: 'PATHRAIYA B MATSAY' from Line 121 in data\today.txt
# ✅ Extracted: 'SONALAL P CHAURASIYA' from Line 122 in data\today.txt
# ✅ Extracted: 'AAYUSHMAN P SEWA' from Line 123 in data\today.txt
# ✅ Extracted: 'TABASSUM BEGAM' from Line 124 in data\today.txt
# ✅ Extracted: 'MUNINDRA P YADAV' from Line 125 in data\today.txt
# ✅ Extracted: 'AJHAR MIYA HAJAM' from Line 126 in data\today.txt
# ✅ Extracted: 'NAVIN JHA' from Line 127 in data\today.txt
# ✅ Extracted: 'GYANI MAHATO' from Line 128 in data\today.txt
# ✅ Extracted: 'LAXMAN KUMAR SAH' from Line 129 in data\today.txt
# ✅ Extracted: 'SURENDRA SAHANI' from Line 130 in data\today.txt
# ✅ Extracted: 'NIRA SAUDEN LIMBU' from Line 131 in data\today.txt
# ✅ Extracted: 'KSHITIJ  KAFLEY' from Line 132 in data\today.txt
# ✅ Extracted: 'TIKA MAYA ACHARYA' from Line 133 in data\today.txt
# ✅ Extracted: 'SURESH DAHAL' from Line 134 in data\today.txt
# ✅ Extracted: 'DIPAK KHATIWADA' from Line 135 in data\today.txt
# ✅ Extracted: 'PUNAM KHATIWADA' from Line 136 in data\today.txt
# ✅ Extracted: 'ARATI N SHRESTHA' from Line 137 in data\today.txt
# ✅ Extracted: 'SWOSTIKA ACHARYA' from Line 138 in data\today.txt
# ✅ Extracted: 'YAGYARAJ THAPA' from Line 139 in data\today.txt
# ✅ Extracted: 'RIMA K. PRAJAPATI' from Line 140 in data\today.txt
# ✅ Extracted: 'SUNAYANA TARAMU' from Line 141 in data\today.txt
# ✅ Extracted: 'SHYAM B CHHANTYAL' from Line 142 in data\today.txt
# ✅ Extracted: 'YASHODHA K JOSHI' from Line 143 in data\today.txt
# ✅ Extracted: 'MANIKA  DANGAURA' from Line 144 in data\today.txt
# ✅ Extracted: 'ANKIT BAM' from Line 145 in data\today.txt
# ✅ Extracted: 'DHRUBA RAJ UPADHYAY' from Line 146 in data\today.txt
# ✅ Extracted: 'RIMA DHAMI' from Line 147 in data\today.txt
# ✅ Extracted: 'IRAK CHAUDHARY' from Line 148 in data\today.txt
# ✅ Extracted: 'PRAKASH B DHAMI' from Line 149 in data\today.txt
# ✅ Extracted: 'BHAGIMAN LIMBU' from Line 150 in data\today.txt
# ✅ Extracted: 'EKA BAHADUR RAI' from Line 151 in data\today.txt
# ✅ Extracted: 'SHYAM B SHRESTHA' from Line 152 in data\today.txt
# ✅ Extracted: 'SAMIR  NEPAL' from Line 153 in data\today.txt
# ✅ Extracted: 'RIM KUMAR LIMBU' from Line 154 in data\today.txt
# ✅ Extracted: 'SARASWATI TAMANG' from Line 155 in data\today.txt
# ✅ Extracted: 'NABIN ALEMAGAR' from Line 156 in data\today.txt
# ✅ Extracted: 'RAJENDRA SAHANI' from Line 157 in data\today.txt
# ✅ Extracted: 'MIN BAHADUR THING' from Line 158 in data\today.txt
# ✅ Extracted: 'AJAY JIMBA' from Line 159 in data\today.txt
# ✅ Extracted: 'TEJ KUMARI DHAMALA' from Line 160 in data\today.txt
# ✅ Extracted: 'KRISHNA P DAHAL' from Line 161 in data\today.txt
# ✅ Extracted: 'JIT BAHADUR GHALAN' from Line 162 in data\today.txt
# ✅ Extracted: 'LAL BAHADUR MOKTAN' from Line 163 in data\today.txt
# ✅ Extracted: 'SABINA OJHA' from Line 164 in data\today.txt
# ✅ Extracted: 'GHAMANDA B B.K.' from Line 165 in data\today.txt
# ✅ Extracted: 'APEKSHA GAIRE' from Line 166 in data\today.txt
# ✅ Extracted: 'UJJAWAL PANTHA' from Line 167 in data\today.txt
# ✅ Extracted: 'TARA DEVI RANA ALE' from Line 168 in data\today.txt
# ✅ Extracted: 'AGNIDHAR CHUWAI' from Line 169 in data\today.txt
# ✅ Extracted: 'BISHWO JIT MALLA' from Line 170 in data\today.txt
# ✅ Extracted: 'ANIL TRIPATHI' from Line 171 in data\today.txt
# ✅ Extracted: 'LAXMI A BHANDARI' from Line 172 in data\today.txt
# ✅ Extracted: 'SUSHILA SHRESTHA' from Line 173 in data\today.txt
# ✅ Extracted: 'DIYA SHRESTHA' from Line 174 in data\today.txt
# ✅ Extracted: 'GANGA RAI' from Line 175 in data\today.txt
# ✅ Extracted: 'SABINA PATHAK' from Line 176 in data\today.txt
# ✅ Extracted: 'KAMALESHWAR KATEL' from Line 177 in data\today.txt
# ✅ Extracted: 'PAMPHA KAMAR' from Line 178 in data\today.txt
# ✅ Extracted: 'SUMANA BHATTARAI' from Line 179 in data\today.txt
# ✅ Extracted: 'RADHIKA PUDASAINI' from Line 180 in data\today.txt
# ✅ Extracted: 'SUMAN TAMANG' from Line 181 in data\today.txt
# ✅ Extracted: 'BAIKUNTHA G.C.' from Line 182 in data\today.txt
# ✅ Extracted: 'SANJU RAI' from Line 183 in data\today.txt
# ✅ Extracted: 'BISHNU M SYANGTAN' from Line 184 in data\today.txt
# ✅ Extracted: 'ASALI JIMBA' from Line 185 in data\today.txt
# ✅ Extracted: 'SABINA LAMA' from Line 186 in data\today.txt
# ✅ Extracted: 'HEMLAL R MATAWALA' from Line 187 in data\today.txt
# ✅ Extracted: 'BAL BAHADUR KARKI' from Line 188 in data\today.txt
# ✅ Extracted: 'HIRA OLI' from Line 189 in data\today.txt
# ✅ Extracted: 'DHANANJAY TAMATA' from Line 190 in data\today.txt
# ✅ Extracted: 'PURNA KALA THAPA' from Line 191 in data\today.txt
# ✅ Extracted: 'SHER BAHADUR RAI' from Line 192 in data\today.txt
# ✅ Extracted: 'SANGE GURUNG' from Line 193 in data\today.txt
# ✅ Extracted: 'CHANDRA KALA RAI' from Line 194 in data\today.txt
# ✅ Extracted: 'UMA KHADGI' from Line 195 in data\today.txt
# ✅ Extracted: 'DEBRAJ SHRESTHA' from Line 196 in data\today.txt
# ✅ Extracted: 'SHIV SHRESTHA' from Line 197 in data\today.txt
# ✅ Extracted: 'SANAM RAI' from Line 198 in data\today.txt
# ✅ Extracted: 'BHIM BAHADUR AIR' from Line 199 in data\today.txt
# ✅ Extracted: 'BASANTA SINGH' from Line 200 in data\today.txt
# ✅ Extracted: 'DAMBAR B GURUNG' from Line 201 in data\today.txt
# ✅ Extracted: 'DIPA SHRESTHA' from Line 202 in data\today.txt
# ✅ Extracted: 'SHANKAR SHRESTHA' from Line 203 in data\today.txt
# ✅ Extracted: 'MAHISHA DHAMALA' from Line 204 in data\today.txt
# ✅ Extracted: 'GEGINDRA B BASNET' from Line 205 in data\today.txt
# ✅ Extracted: 'GANESH B THAPA' from Line 206 in data\today.txt
# ✅ Extracted: 'BHOJ KUMARI GAUTAM' from Line 207 in data\today.txt
# ✅ Extracted: 'BHUWAN KAFLE' from Line 208 in data\today.txt
# ✅ Extracted: 'TARA K ADHIKARI' from Line 209 in data\today.txt
# ✅ Extracted: 'JEEBAN K SHRESTHA' from Line 210 in data\today.txt
# ✅ Extracted: 'LIL B SHRESTHA' from Line 211 in data\today.txt
# ✅ Extracted: 'BHAGWATI B K' from Line 212 in data\today.txt
# ✅ Extracted: 'RITA  RAI' from Line 213 in data\today.txt
# ✅ Extracted: 'BIKASH KARKI' from Line 214 in data\today.txt
# ✅ Extracted: 'MUKESH NEPALI' from Line 215 in data\today.txt
# ✅ Extracted: 'KABIN SHERMA' from Line 216 in data\today.txt
# ✅ Extracted: 'DIPIKA RAI' from Line 217 in data\today.txt
# ✅ Extracted: 'BIMALA A SHANKHI' from Line 218 in data\today.txt
# ✅ Extracted: 'NIRA PARIYAR' from Line 219 in data\today.txt
# ✅ Extracted: 'SUSMITA THAPA' from Line 220 in data\today.txt
# ✅ Extracted: 'RAM BAHADUR ALE' from Line 221 in data\today.txt
# ✅ Extracted: 'NARENDRA SUNAR' from Line 222 in data\today.txt
# ✅ Extracted: 'ABINAS KASAI' from Line 223 in data\today.txt
# ✅ Extracted: 'GYAPCHAMAN TAMANG' from Line 224 in data\today.txt
# ✅ Extracted: 'BASANTA GURUNG' from Line 225 in data\today.txt
# ✅ Extracted: 'INDU KUMARI HARIJAN' from Line 226 in data\today.txt
# ✅ Extracted: 'KANHAI YADAV' from Line 227 in data\today.txt
# ✅ Extracted: 'OM PRAKASH KURMI' from Line 228 in data\today.txt
# ✅ Extracted: 'MEGHA KARN' from Line 229 in data\today.txt
# ✅ Extracted: 'NIRMALA DEVKOTA' from Line 230 in data\today.txt
# ✅ Extracted: 'LOK BDR BUDHATHOKI' from Line 231 in data\today.txt
# ✅ Extracted: 'LALIT KUMAR GUPTA' from Line 232 in data\today.txt
# ✅ Extracted: 'BINOD KUMAR SHAHI' from Line 233 in data\today.txt
# ✅ Extracted: 'DHYAN MURAU' from Line 234 in data\today.txt
# ✅ Extracted: 'ABDUL SALAM HALWAI' from Line 235 in data\today.txt
# ✅ Extracted: 'SHOBHA SHAH' from Line 236 in data\today.txt
# ✅ Extracted: 'DIPENDRA S THAKURI' from Line 237 in data\today.txt
# ✅ Extracted: 'KALAMUDDIN RAI' from Line 238 in data\today.txt
# ✅ Extracted: 'PRAKASH GAUTAM' from Line 239 in data\today.txt
# ✅ Extracted: 'SHOBHA CHAUDHARY' from Line 240 in data\today.txt
# ✅ Extracted: 'BHAWANI P NEUPANE' from Line 241 in data\today.txt
# ✅ Extracted: 'HAJRAT ALI SAE' from Line 242 in data\today.txt
# ✅ Extracted: 'SHANTI CHAUDHARY' from Line 243 in data\today.txt
# ✅ Extracted: 'BISHNU THAPA' from Line 244 in data\today.txt
# ✅ Extracted: 'KAMAL RAJ JAISHI' from Line 245 in data\today.txt
# ✅ Extracted: 'RAJANI D CHAUDHARY' from Line 246 in data\today.txt
# ✅ Extracted: 'DHARMENDRA AIDEE' from Line 247 in data\today.txt
# ✅ Extracted: 'RUPA TAMATTA' from Line 248 in data\today.txt
# ✅ Extracted: 'SHER BAHADUR SINGH' from Line 249 in data\today.txt
# ✅ Extracted: 'BHAWANA AWASTHI' from Line 250 in data\today.txt
# ✅ Extracted: 'SONURAM CHAUDHARY' from Line 251 in data\today.txt
# ✅ Extracted: 'DIPAK BAHADUR SINGH' from Line 252 in data\today.txt
# ✅ Extracted: 'YOGESH JORA' from Line 253 in data\today.txt
# ✅ Extracted: 'MANGITLA M LIMBU' from Line 254 in data\today.txt
# ✅ Extracted: 'PHUNGITLA M LIMBU' from Line 255 in data\today.txt
# ✅ Extracted: 'SHIKHA KAFLE' from Line 256 in data\today.txt
# ✅ Extracted: 'SHUSMA KEDEM' from Line 257 in data\today.txt
# ✅ Extracted: 'PRAMILA POKHAREL' from Line 258 in data\today.txt
# ✅ Extracted: 'SHREE MAYA GURUNG' from Line 259 in data\today.txt
# ✅ Extracted: 'KAMALA LIMBU' from Line 260 in data\today.txt
# ✅ Extracted: 'SMRITI RAI' from Line 261 in data\today.txt
# ✅ Extracted: 'SHASIKA RAI' from Line 262 in data\today.txt
# ✅ Extracted: 'SABITRI  LIMBU' from Line 263 in data\today.txt
# ✅ Extracted: 'BINA RAI' from Line 264 in data\today.txt
# ✅ Extracted: 'MAYA DEBI TAMANG' from Line 265 in data\today.txt
# ✅ Extracted: 'KAMALA RAI' from Line 266 in data\today.txt
# ✅ Extracted: 'NARENDRA YAKHA' from Line 267 in data\today.txt
# ✅ Extracted: 'SUNNY PRADHAN' from Line 268 in data\today.txt
# ✅ Extracted: 'SHIVA KUMAR YOGI' from Line 269 in data\today.txt
# ✅ Extracted: 'ASHA RAI' from Line 270 in data\today.txt
# ✅ Extracted: 'TULASA K POKHREL' from Line 271 in data\today.txt
# ✅ Extracted: 'RAM CHANDRA RAI' from Line 272 in data\today.txt
# ✅ Extracted: 'ESMARY SUBBA LIMBU' from Line 273 in data\today.txt
# ✅ Extracted: 'SHREEPARSAD LIMBU' from Line 274 in data\today.txt
# ✅ Extracted: 'SUMAN PANDIT' from Line 275 in data\today.txt
# ✅ Extracted: 'PRAKRITI TIWARI' from Line 276 in data\today.txt
# ✅ Extracted: 'PRAMOD REGMI' from Line 277 in data\today.txt
# ✅ Extracted: 'NAWARAJ REGMI' from Line 278 in data\today.txt
# ✅ Extracted: 'BISNU NEPALI' from Line 279 in data\today.txt
# ✅ Extracted: 'PRAKASH JAISI' from Line 280 in data\today.txt
# ✅ Extracted: 'RAMCHANDRA JAISI' from Line 281 in data\today.txt
# ✅ Extracted: 'CHANDRA B KHADKA' from Line 282 in data\today.txt
# ✅ Extracted: 'KRITILAL JAISI' from Line 283 in data\today.txt
# ✅ Extracted: 'SUNITA BOHARA SINGH' from Line 284 in data\today.txt
# ✅ Extracted: 'SRISHTI SHAHI SINGH' from Line 285 in data\today.txt
# ✅ Extracted: 'DHAN BAHADUR SINGH' from Line 286 in data\today.txt
# ✅ Extracted: 'KHADKA B CHALAUNE' from Line 287 in data\today.txt
# ✅ Extracted: 'DEUSARA JAISI' from Line 288 in data\today.txt
# ✅ Extracted: 'KARNA B KHADKA' from Line 289 in data\today.txt
# ✅ Extracted: 'KRISHNA P JAISI' from Line 290 in data\today.txt
# ✅ Extracted: 'BISHNU SHAHI' from Line 291 in data\today.txt
# ✅ Extracted: 'BHIM BAHADUR TIRUWA' from Line 292 in data\today.txt
# ✅ Extracted: 'BIPANA NEPALI' from Line 293 in data\today.txt
# ✅ Extracted: 'CHAKRA B SINGH' from Line 294 in data\today.txt
# ✅ Extracted: 'SHARADA A BASNET' from Line 295 in data\today.txt
# ✅ Extracted: 'NIM BAHADUR DAMAI' from Line 296 in data\today.txt
# ✅ Extracted: 'BHARAT B SINGH' from Line 297 in data\today.txt
# ✅ Extracted: 'BIRENDRA B SIGHN' from Line 298 in data\today.txt
# ✅ Extracted: 'JANAK BAHADUR THAPA' from Line 299 in data\today.txt
# ✅ Extracted: 'MINIKA SHAHI SINGH' from Line 300 in data\today.txt
# ✅ Extracted: 'SITA KUMARI ROKAYA' from Line 301 in data\today.txt
# ✅ Extracted: 'KARNA JUNG SHAH' from Line 302 in data\today.txt
# ✅ Extracted: 'PREM BAHADUR SHAHI' from Line 303 in data\today.txt
# ✅ Extracted: 'AMALA . SHAHI' from Line 304 in data\today.txt
# ✅ Extracted: 'BISHNU JAISI' from Line 305 in data\today.txt
# ✅ Extracted: 'RAMESH KUMAR BASNET' from Line 306 in data\today.txt
# ✅ Extracted: 'KALIKA SHAHI' from Line 307 in data\today.txt
# ✅ Extracted: 'MAN BAHADUR SINGH' from Line 308 in data\today.txt
# ✅ Extracted: 'HARI SHARAN LAMSAL' from Line 309 in data\today.txt
# ✅ Extracted: 'KIRAN KHADKA' from Line 310 in data\today.txt
# ✅ Extracted: 'UMESH KUMAR THAPA' from Line 311 in data\today.txt
# ✅ Extracted: 'SHALIK RAM PARAJULI' from Line 312 in data\today.txt
# ✅ Extracted: 'KISHAN A KRISHI' from Line 313 in data\today.txt
# ✅ Extracted: 'SITA NEGI' from Line 314 in data\today.txt
# ✅ Extracted: 'PUJA DAMAI' from Line 315 in data\today.txt
# ✅ Extracted: 'BEBINA THAPA MAGAR' from Line 316 in data\today.txt
# ✅ Extracted: 'SONIYA CHAND' from Line 317 in data\today.txt
# ✅ Extracted: 'HIMANI SUNAR TIRUWA' from Line 318 in data\today.txt
# ✅ Extracted: 'KARESHMA KARKI' from Line 319 in data\today.txt
# ✅ Extracted: 'PRINKA KHADKA' from Line 320 in data\today.txt
# ✅ Extracted: 'KARUNAKAR BHATTA' from Line 321 in data\today.txt
# ✅ Extracted: 'BINDU KUMARI SAUD' from Line 322 in data\today.txt
# ✅ Extracted: 'RAJESH  SUNAR' from Line 323 in data\today.txt
# ✅ Extracted: 'SABITA SHAHI' from Line 324 in data\today.txt
# ✅ Extracted: 'USHA SUNAR' from Line 325 in data\today.txt
# ✅ Extracted: 'PRAMILA KU BHAT' from Line 326 in data\today.txt
# ✅ Extracted: 'BHAWANA JAIRUP' from Line 327 in data\today.txt
# ✅ Extracted: 'BISHAL THAPA MAGAR' from Line 328 in data\today.txt
# ✅ Extracted: 'GANESH B KHATRI' from Line 329 in data\today.txt
# ✅ Extracted: 'HIMANI GIRI' from Line 330 in data\today.txt
# ✅ Extracted: 'BADRI DAMAI' from Line 331 in data\today.txt
# ✅ Extracted: 'BUDDHA LAXMI  BAIJU' from Line 332 in data\today.txt
# ✅ Extracted: 'CHAMPAK  SUBEDI' from Line 333 in data\today.txt
# ✅ Extracted: 'RABIN JOSHI' from Line 334 in data\today.txt
# ✅ Extracted: 'SATYA RAM BASUKALA' from Line 335 in data\today.txt
# ✅ Extracted: 'LAXMI SUNDAR  SUWAL' from Line 336 in data\today.txt
# ✅ Extracted: 'SUNTALI LAMICHHANE' from Line 337 in data\today.txt
# ✅ Extracted: 'BHIM BAHADUR BATA' from Line 338 in data\today.txt
# ✅ Extracted: 'SURESH PD.  NEUPANE' from Line 339 in data\today.txt
# ✅ Extracted: 'GANESH MAN  KOJU' from Line 340 in data\today.txt
# ✅ Extracted: 'RAM C BHUJU' from Line 341 in data\today.txt
# ✅ Extracted: 'NARAYAN KUMAR MAJHI' from Line 342 in data\today.txt
# ✅ Extracted: 'SARITA CHAUDHARY' from Line 343 in data\today.txt
# ✅ Extracted: 'TANUJA CHAUDHARY' from Line 344 in data\today.txt
# ✅ Extracted: 'GITA KUMARI SAH' from Line 345 in data\today.txt
# ✅ Extracted: 'RAM BILASH MANDAL' from Line 346 in data\today.txt
# ✅ Extracted: 'GANGA KUMARI YOGI' from Line 347 in data\today.txt
# ✅ Extracted: 'BISHNA B SHAHI' from Line 348 in data\today.txt
# ✅ Extracted: 'GANGA KUMARI KHATRI' from Line 349 in data\today.txt
# ✅ Extracted: 'GYANENDRA B SHRESTHA' from Line 350 in data\today.txt
# ✅ Extracted: 'BIMALA RANA' from Line 351 in data\today.txt
# ✅ Extracted: 'PURNIMA PUN BUDHA' from Line 352 in data\today.txt
# ✅ Extracted: 'PRADIP BUDHA MAGAR' from Line 353 in data\today.txt
# ✅ Extracted: 'SARAHANA S THAKURI' from Line 354 in data\today.txt
# ✅ Extracted: 'KSHETRA B KATUWAL' from Line 355 in data\today.txt
# ✅ Extracted: 'NABIN KARKI' from Line 356 in data\today.txt
# ✅ Extracted: 'APAR KARKI' from Line 357 in data\today.txt
# ✅ Extracted: 'GYANENDRA B RAI' from Line 358 in data\today.txt
# ✅ Extracted: 'MADAN KUMAR MAGAR' from Line 359 in data\today.txt
# ✅ Extracted: 'SHARAD G STORE' from Line 360 in data\today.txt
# ✅ Extracted: 'SHOVA B BHANDARI' from Line 361 in data\today.txt
# ✅ Extracted: 'PABITRA SOMAI' from Line 362 in data\today.txt
# ✅ Extracted: 'ABHINAB KHANAL' from Line 363 in data\today.txt
# ✅ Extracted: 'RITA SHRESTHA' from Line 364 in data\today.txt
# ✅ Extracted: 'ISHWOR THUYA' from Line 365 in data\today.txt
# ✅ Extracted: 'UNISHA GAINJU' from Line 366 in data\today.txt
# ✅ Extracted: 'MAIYA SHRESTHA' from Line 367 in data\today.txt
# ✅ Extracted: 'DHIRENDRA K SINGH' from Line 368 in data\today.txt
# ✅ Extracted: 'KABITA PANDEY' from Line 369 in data\today.txt
# ✅ Extracted: 'BIRBAHADUR SAH' from Line 370 in data\today.txt
# ✅ Extracted: 'MADHURI KUMARI' from Line 371 in data\today.txt
# ✅ Extracted: 'KHIMA K C' from Line 372 in data\today.txt
# ✅ Extracted: 'BHIM KUMARI K' from Line 373 in data\today.txt
# ✅ Extracted: 'LAXMI MALLA' from Line 374 in data\today.txt
# ✅ Extracted: 'BINOD SHAHA' from Line 375 in data\today.txt
# ✅ Extracted: 'ANJANA GHARTI' from Line 376 in data\today.txt
# ✅ Extracted: 'SUNITA OLI' from Line 377 in data\today.txt
# ✅ Extracted: 'DEV BAHADUR BATHA' from Line 378 in data\today.txt
# ✅ Extracted: 'SHOVA RAM SUNAR' from Line 379 in data\today.txt
# ✅ Extracted: 'SHANKAR PACHHAI' from Line 380 in data\today.txt
# ✅ Extracted: 'RAM MAYA PATHAK' from Line 381 in data\today.txt
# ✅ Extracted: 'LAXMI OLI' from Line 382 in data\today.txt
# ✅ Extracted: 'PUJA BEAUTY PALOUR' from Line 383 in data\today.txt
# ✅ Extracted: 'SANAD NIRMAN SEWA' from Line 384 in data\today.txt
# ✅ Extracted: 'BINITA ACHHAMI' from Line 385 in data\today.txt
# ✅ Extracted: 'UDAY SINGH THAKURI' from Line 386 in data\today.txt
# ✅ Extracted: 'MINA K BHANDARI' from Line 387 in data\today.txt
# ✅ Extracted: 'SUDIP D.J. TENT' from Line 388 in data\today.txt
# ✅ Extracted: 'RAMGOPAL GODIYA' from Line 389 in data\today.txt
# ✅ Extracted: 'SHARMILA THAPA' from Line 390 in data\today.txt
# ✅ Extracted: 'JENISH SHRESTHA' from Line 391 in data\today.txt
# ✅ Extracted: 'DURGA MAN LAMA' from Line 392 in data\today.txt
# ✅ Extracted: 'NAND KUMARI MAHATO' from Line 393 in data\today.txt
# ✅ Extracted: 'SOM BAHADUR HAYU' from Line 394 in data\today.txt
# ✅ Extracted: 'APSON P TAMANG' from Line 395 in data\today.txt
# ✅ Extracted: 'SUBHAS SUNAR' from Line 396 in data\today.txt
# ✅ Extracted: 'BISNU MAYA REGMI' from Line 397 in data\today.txt
# ✅ Extracted: 'KANCHAN THAPA' from Line 398 in data\today.txt
# ✅ Extracted: 'BISHNU MAYA PARIYAR' from Line 399 in data\today.txt
# ✅ Extracted: 'MANISH ADHIKARI' from Line 400 in data\today.txt
# ✅ Extracted: 'BIKESH KUMAR SHAH' from Line 401 in data\today.txt
# ✅ Extracted: 'MUMTAJ ALAM' from Line 402 in data\today.txt
# ✅ Extracted: 'RAMESH K CHAUDHARY' from Line 403 in data\today.txt
# ✅ Extracted: 'PRAKASH THAPA MAGAR' from Line 404 in data\today.txt
# ✅ Extracted: 'TARA NATH CHAUDHARY' from Line 405 in data\today.txt
# ✅ Extracted: 'BIHANI RAYA KSHETRI' from Line 406 in data\today.txt
# ✅ Extracted: 'UPENDRA P YADAV' from Line 407 in data\today.txt
# ✅ Extracted: 'ROJINA CHAULAGAIN' from Line 408 in data\today.txt
# ✅ Extracted: 'SUK LAL PAKHRIN' from Line 409 in data\today.txt
# ✅ Extracted: 'MOHAN KUAMR GAUTAM' from Line 410 in data\today.txt
# ✅ Extracted: 'SUNITA GHALAN' from Line 411 in data\today.txt
# ✅ Extracted: 'SONI LAMA GHALAN' from Line 412 in data\today.txt
# ✅ Extracted: 'PUJA WAIBA' from Line 413 in data\today.txt
# ✅ Extracted: 'MANILA GHALAN' from Line 414 in data\today.txt
# ✅ Extracted: 'PRITIKA PRADHAN' from Line 415 in data\today.txt
# ✅ Extracted: 'SAGUN BHATTARAI' from Line 416 in data\today.txt
# ✅ Extracted: 'NABINA KHADKA' from Line 417 in data\today.txt
# ✅ Extracted: 'SUKURAM LOPCHAN' from Line 418 in data\today.txt
# ✅ Extracted: 'MANOJ KUMAR SAH' from Line 419 in data\today.txt
# ✅ Extracted: 'ARUNA GOLE' from Line 420 in data\today.txt
# ✅ Extracted: 'HARISHARAN NEUPANE' from Line 421 in data\today.txt
# ✅ Extracted: 'RACHANA THOKAR' from Line 422 in data\today.txt
# ✅ Extracted: 'RAM BAHADUR  KUMALE' from Line 423 in data\today.txt
# ✅ Extracted: 'DIPAK SHRESTHA' from Line 424 in data\today.txt
# ✅ Extracted: 'PRAMILA MUKTAN' from Line 425 in data\today.txt
# ✅ Extracted: 'SUSMITA BOHORA' from Line 426 in data\today.txt
# ✅ Extracted: 'RANJANA K TAMANG' from Line 427 in data\today.txt
# ✅ Extracted: 'KUMARI TITUNG' from Line 428 in data\today.txt
# ✅ Extracted: 'SHASHI KUMAR YADAV' from Line 429 in data\today.txt
# ✅ Extracted: 'MANMAYA MUKTAN' from Line 430 in data\today.txt
# ✅ Extracted: 'SUBASH PATHAK' from Line 431 in data\today.txt
# ✅ Extracted: 'JIT BAHADUR RUMBA' from Line 432 in data\today.txt
# ✅ Extracted: 'TEKAR P GHIMIRE' from Line 433 in data\today.txt
# ✅ Extracted: 'RABIKUMAR SHRESTHA' from Line 434 in data\today.txt
# ✅ Extracted: 'KRISHNA MAYA NEUPANE' from Line 435 in data\today.txt
# ✅ Extracted: 'PRAKRITI GAUTAM' from Line 436 in data\today.txt
# ✅ Extracted: 'AAKRITI MUKTAN' from Line 437 in data\today.txt
# ✅ Extracted: 'KAMALA RUMBA' from Line 438 in data\today.txt
# ✅ Extracted: 'BINISHA MISHRA' from Line 439 in data\today.txt
# ✅ Extracted: 'KARUNA GOLE' from Line 440 in data\today.txt
# ✅ Extracted: 'SUNIL RUMBA' from Line 441 in data\today.txt
# ✅ Extracted: 'ASMITA BHATTARAI' from Line 442 in data\today.txt
# ✅ Extracted: 'CHITRA B THAPA' from Line 443 in data\today.txt
# ✅ Extracted: 'NILAM MASKEY' from Line 444 in data\today.txt
# ✅ Extracted: 'AAISOR NAU' from Line 445 in data\today.txt
# ✅ Extracted: 'SANGITA SUNAR' from Line 446 in data\today.txt
# ✅ Extracted: 'GITA THAPA' from Line 447 in data\today.txt
# ✅ Extracted: 'SAMJHANA THAPA' from Line 448 in data\today.txt
# ✅ Extracted: 'SARITA SAPKOTA' from Line 449 in data\today.txt
# ✅ Extracted: 'KAMANA BHATTARAI' from Line 450 in data\today.txt
# ✅ Extracted: 'NUMAKALA NEPALI' from Line 451 in data\today.txt
# ✅ Extracted: 'SANGITA KAFLE' from Line 452 in data\today.txt
# ✅ Extracted: 'REJINA SUNAR' from Line 453 in data\today.txt
# ✅ Extracted: 'PRITHVI RANA MAGAR' from Line 454 in data\today.txt
# ✅ Extracted: 'LISA THAPA' from Line 455 in data\today.txt
# ✅ Extracted: 'NARAYAN P ACHARYA' from Line 456 in data\today.txt
# ✅ Extracted: 'BHUPRAJ BASNET' from Line 457 in data\today.txt
# ✅ Extracted: 'RONIKA  KOIRALA' from Line 458 in data\today.txt
# ✅ Extracted: 'GUNARAJ POKHREL' from Line 459 in data\today.txt
# ✅ Extracted: 'LALITA CHAUDHARY' from Line 460 in data\today.txt
# ✅ Extracted: 'JITENDRA RAI' from Line 461 in data\today.txt
# ✅ Extracted: 'MAHENDRA TAMANG' from Line 462 in data\today.txt
# ✅ Extracted: 'BABU RAM DAHAL' from Line 463 in data\today.txt
# ✅ Extracted: 'TILAK B KHATRI' from Line 464 in data\today.txt
# ✅ Extracted: 'ANAMIKA SINGH' from Line 465 in data\today.txt
# ✅ Extracted: 'JANUKA GAUTAM' from Line 466 in data\today.txt
# ✅ Extracted: 'RINA B PAKHARIN' from Line 467 in data\today.txt
# ✅ Extracted: 'CHINA SAPKOTA' from Line 468 in data\today.txt
# ✅ Extracted: 'BIPLAV  NEUPANE' from Line 469 in data\today.txt
# ✅ Extracted: 'AMAR BAHADUR  SHRESTHA' from Line 470 in data\today.txt
# ✅ Extracted: 'AMULA KUMARI YADHAV' from Line 471 in data\today.txt
# ✅ Extracted: 'MANISH SAPKOTA' from Line 472 in data\today.txt
# ✅ Extracted: 'SAMJHANA KHANAL' from Line 473 in data\today.txt
# ✅ Extracted: 'AMAR LAMA' from Line 474 in data\today.txt
# ✅ Extracted: 'HEM KUMAR KARKI' from Line 475 in data\today.txt
# ✅ Extracted: 'UMESH KUMAR SHARMA  PARAJ' from Line 476 in data\today.txt
# ✅ Extracted: 'ARJUN RAI' from Line 477 in data\today.txt
# ✅ Extracted: 'LISANU THARU' from Line 478 in data\today.txt
# ✅ Extracted: 'NETRA B NEPALI' from Line 479 in data\today.txt
# ✅ Extracted: 'MUKUND JOSHI' from Line 480 in data\today.txt
# ✅ Extracted: 'HIKMAT BAHADUR SAUD' from Line 481 in data\today.txt
# ✅ Extracted: 'NARAYAN KUMAR  REGMI' from Line 482 in data\today.txt
# ✅ Extracted: 'SURESH NEGI' from Line 483 in data\today.txt
# ✅ Extracted: 'SURAJ  SHARMA' from Line 484 in data\today.txt
# ✅ Extracted: 'DIPIKA KUNWAR' from Line 485 in data\today.txt
# ✅ Extracted: 'PRABESH MARASINI' from Line 486 in data\today.txt
# ✅ Extracted: 'BIJAYA BASYAL' from Line 487 in data\today.txt
# ✅ Extracted: 'GIRDHARI P CHAUDHARY' from Line 488 in data\today.txt
# ✅ Extracted: 'KUMAR TIMILSENA' from Line 489 in data\today.txt
# ✅ Extracted: 'GOBINDA THAPA' from Line 490 in data\today.txt
# ✅ Extracted: 'NARESH KUMAR  SAH' from Line 491 in data\today.txt
# ✅ Extracted: 'RAMESH BUDHADHOKI' from Line 492 in data\today.txt
# ✅ Extracted: 'CHAMELI REGMI' from Line 493 in data\today.txt
# ✅ Extracted: 'HEMRAJ RAI' from Line 494 in data\today.txt
# ✅ Extracted: 'DINESH NEPALI' from Line 495 in data\today.txt
# ✅ Extracted: 'SITA BISHOWKARMA' from Line 496 in data\today.txt
# ✅ Extracted: 'AASHA K. THAKUR' from Line 497 in data\today.txt
# ✅ Extracted: 'YUBRAJ GYAWALI' from Line 498 in data\today.txt
# ✅ Extracted: 'SHIVPRASAD CHAUDHARY' from Line 499 in data\today.txt
# ✅ Extracted: 'BUDDHA BHANDARI' from Line 500 in data\today.txt
# ✅ Extracted: 'UMA GIRI' from Line 501 in data\today1.txt
# ✅ Extracted: 'SAGAR UPADHYA' from Line 502 in data\today1.txt
# ✅ Extracted: 'GITANJALI SINGH' from Line 503 in data\today1.txt
# ✅ Extracted: 'PHURBA SHERPA' from Line 504 in data\today1.txt
# ✅ Extracted: 'BAREK KUMARI DARJI' from Line 505 in data\today1.txt
# ✅ Extracted: 'KISHAN GURUNG' from Line 506 in data\today1.txt
# ✅ Extracted: 'SARASWATI K SHAHI' from Line 507 in data\today1.txt
# ✅ Extracted: 'KARNA B CHANDARA' from Line 508 in data\today1.txt
# ✅ Extracted: 'BHIM BAHADUR NEPALI' from Line 509 in data\today1.txt
# ✅ Extracted: 'TILAK BAHADUR SINGH' from Line 510 in data\today1.txt
# ✅ Extracted: 'AIN BAHADUR SINGH' from Line 511 in data\today1.txt
# ✅ Extracted: 'SURESH  POKHREL' from Line 512 in data\today1.txt
# ✅ Extracted: 'AMIN MAINALI' from Line 513 in data\today1.txt
# ✅ Extracted: 'SHUSILA SHRESTHA' from Line 514 in data\today1.txt
# ✅ Extracted: 'ABDULLA  KHAN' from Line 515 in data\today1.txt
# ✅ Extracted: 'KAPILDEV MEHTA' from Line 516 in data\today1.txt
# ✅ Extracted: 'ISHORA KAFLE' from Line 517 in data\today1.txt
# ✅ Extracted: 'LELIN MAGAR' from Line 518 in data\today1.txt
# ✅ Extracted: 'SAPANA SHRESTHA' from Line 519 in data\today1.txt
# ✅ Extracted: 'BISHAL KHANAL' from Line 520 in data\today1.txt
# ✅ Extracted: 'SONY RAI' from Line 521 in data\today1.txt
# ✅ Extracted: 'SANDESH B BISTA' from Line 522 in data\today1.txt
# ✅ Extracted: 'KHAGENDRA K BHARATI' from Line 523 in data\today1.txt
# ✅ Extracted: 'KAMALA DANGAL' from Line 524 in data\today1.txt
# ✅ Extracted: 'MUNA BHATTARAI' from Line 525 in data\today1.txt
# ✅ Extracted: 'JAGADISH KAFLE' from Line 526 in data\today1.txt
# ✅ Extracted: 'KABITA KHADKA' from Line 527 in data\today1.txt
# ✅ Extracted: 'SURITA SINGH' from Line 528 in data\today1.txt
# ✅ Extracted: 'SUMITRA B.K' from Line 529 in data\today1.txt
# ✅ Extracted: 'RUPESH KUMAR SINGH' from Line 530 in data\today1.txt
# ✅ Extracted: 'HARI PRASAD GHIMIRE' from Line 531 in data\today1.txt
# ✅ Extracted: 'LAXMI K HARIJAN' from Line 532 in data\today1.txt
# ✅ Extracted: 'SABITA BHAT CHHETRI' from Line 533 in data\today1.txt
# ✅ Extracted: 'GOPAL ACHARYA' from Line 534 in data\today1.txt
# ✅ Extracted: 'BUDDHI B PANDEY' from Line 535 in data\today1.txt
# ✅ Extracted: 'SAPANA PARIYAR' from Line 536 in data\today1.txt
# ✅ Extracted: 'NANDA DEVI DAMAI' from Line 537 in data\today1.txt
# ✅ Extracted: 'PRAKASH JOSHI' from Line 538 in data\today1.txt
# ✅ Extracted: 'A K KHAJA' from Line 539 in data\today1.txt
# ✅ Extracted: 'SUBASH TAMRAKAR' from Line 540 in data\today1.txt
# ✅ Extracted: 'SHER BAHADUR BOHARA' from Line 541 in data\today1.txt
# ✅ Extracted: 'TULASI JOSHI' from Line 542 in data\today1.txt
# ✅ Extracted: 'DURGI NEPALI' from Line 543 in data\today1.txt
# ✅ Extracted: 'DABAL SAUD' from Line 544 in data\today1.txt
# ✅ Extracted: 'RAJENDRA B SAUD' from Line 545 in data\today1.txt
# ✅ Extracted: 'SARASWOTI M. DEUBA' from Line 546 in data\today1.txt
# ✅ Extracted: 'UJWAL BASNET' from Line 547 in data\today1.txt
# ✅ Extracted: 'KANCHI MAYA TAMANG' from Line 548 in data\today1.txt
# ✅ Extracted: 'PASANG DORJE LAMA' from Line 549 in data\today1.txt
# ✅ Extracted: 'KARMA LAMA' from Line 550 in data\today1.txt
# ✅ Extracted: 'SAPANA TAMANG' from Line 551 in data\today1.txt
# ✅ Extracted: 'DAMODAR DHUNGEL' from Line 552 in data\today1.txt
# ✅ Extracted: 'MEEN BAHADUR RAWAL' from Line 553 in data\today1.txt
# ✅ Extracted: 'BIMALA KUMAI' from Line 554 in data\today1.txt
# ✅ Extracted: 'BIBEK KUMAR YADAV' from Line 555 in data\today1.txt
# ✅ Extracted: 'BINDAWA AHIRIN' from Line 556 in data\today1.txt
# ✅ Extracted: 'BIJAY KUMAR YADAV' from Line 557 in data\today1.txt
# ✅ Extracted: 'RASIDA AKHTAR' from Line 558 in data\today1.txt
# ✅ Extracted: 'KHAGENDRA S DHAMI' from Line 559 in data\today1.txt
# ✅ Extracted: 'MAHENDRA GIRI' from Line 560 in data\today1.txt
# ✅ Extracted: 'SHANKAR TAMANG' from Line 561 in data\today1.txt
# ✅ Extracted: 'PRAMILA  KOIRALA' from Line 562 in data\today1.txt
# ✅ Extracted: 'NARAYAN PD POKHAREL' from Line 563 in data\today1.txt
# ✅ Extracted: 'NILAKANTHA POUDEL' from Line 564 in data\today1.txt
# ✅ Extracted: 'MAN BAHADUR THAPA' from Line 565 in data\today1.txt
# ✅ Extracted: 'GANGA K KHATRI' from Line 566 in data\today1.txt
# ✅ Extracted: 'PRADIP K UPADHYAY' from Line 567 in data\today1.txt
# ✅ Extracted: 'ANUSA BHOLAN' from Line 568 in data\today1.txt
# ✅ Extracted: 'HARI SHARAN REGMI' from Line 569 in data\today1.txt
# ✅ Extracted: 'INDIRA GURUNG' from Line 570 in data\today1.txt
# ✅ Extracted: 'MANITA NECHAL' from Line 571 in data\today1.txt
# ✅ Extracted: 'RAJU PAUDEL' from Line 572 in data\today1.txt
# ✅ Extracted: 'SAJJAN  REGMI' from Line 573 in data\today1.txt
# ✅ Extracted: 'BABURAJA MAHARJAN' from Line 574 in data\today1.txt
# ✅ Extracted: 'HIMAL B.K.' from Line 575 in data\today1.txt
# ✅ Extracted: 'BALARAM SHRESTHA' from Line 576 in data\today1.txt
# ✅ Extracted: 'DIPTI G MAHARJAN' from Line 577 in data\today1.txt
# ✅ Extracted: 'SUMITRA K MAGAR' from Line 578 in data\today1.txt
# ✅ Extracted: 'TIKA RAM PANDEY' from Line 579 in data\today1.txt
# ✅ Extracted: 'BHIM KUMARI RAI' from Line 580 in data\today1.txt
# ✅ Extracted: 'TIKA RAM LIMBU' from Line 581 in data\today1.txt
# ✅ Extracted: 'SEEMA SUBEDI' from Line 582 in data\today1.txt
# ✅ Extracted: 'MAIMA BHANDARI' from Line 583 in data\today1.txt
# ✅ Extracted: 'SAKILA BISHWAKARMA' from Line 584 in data\today1.txt
# ✅ Extracted: 'SABITRI BHANDARI' from Line 585 in data\today1.txt
# ✅ Extracted: 'NARAYAN MAHARJAN' from Line 586 in data\today1.txt
# ✅ Extracted: 'TIKA B GHATANI' from Line 587 in data\today1.txt
# ✅ Extracted: 'KHEM B.THAPA  MAGAR' from Line 588 in data\today1.txt
# ✅ Extracted: 'KIRAN THAPA MAGAR' from Line 589 in data\today1.txt
# ✅ Extracted: 'MUKESH KUMAR RAM' from Line 590 in data\today1.txt
# ✅ Extracted: 'PAWAN KUMARI MALIK' from Line 591 in data\today1.txt
# ✅ Extracted: 'JAIFUL KHATUN' from Line 592 in data\today1.txt
# ✅ Extracted: 'NIRILA K CHAUDHARY' from Line 593 in data\today1.txt
# ✅ Extracted: 'NIBHA K CHAUDHARY' from Line 594 in data\today1.txt
# ✅ Extracted: 'RAJIV K CHAUDHARI' from Line 595 in data\today1.txt
# ✅ Extracted: 'SAMJHANA SUNAR RAI' from Line 596 in data\today1.txt
# ✅ Extracted: 'KISHAN BASNET' from Line 597 in data\today1.txt
# ✅ Extracted: 'BADRI KUMAR MAJHI' from Line 598 in data\today1.txt
# ✅ Extracted: 'RAMESH KUMAR BASNET' from Line 599 in data\today1.txt
# ✅ Extracted: 'SANTOSH KARKI' from Line 600 in data\today1.txt
# ✅ Extracted: 'NIKHITA MAJHI' from Line 601 in data\today1.txt
# ✅ Extracted: 'AADITYA CHALISE' from Line 602 in data\today1.txt
# ✅ Extracted: 'NIKHIL MAJHI' from Line 603 in data\today1.txt
# ✅ Extracted: 'BINA SHRESTHA' from Line 604 in data\today1.txt
# ✅ Extracted: 'NAIN B SHRESTHA' from Line 605 in data\today1.txt
# ✅ Extracted: 'HARISHCHANDRA KANDEL' from Line 606 in data\today1.txt
# ✅ Extracted: 'SUNITA  DHAKAL' from Line 607 in data\today1.txt
# ✅ Extracted: 'ANITA MAYA DONG' from Line 608 in data\today1.txt
# ✅ Extracted: 'PRANETA BHATTARAI' from Line 609 in data\today1.txt
# ✅ Extracted: 'SHANTI MAYA SYANGBO' from Line 610 in data\today1.txt
# ✅ Extracted: 'SMRITI RANA MAGAR' from Line 611 in data\today1.txt
# ✅ Extracted: 'KAMAL RAJ SAHAKARI' from Line 612 in data\today1.txt
# ✅ Extracted: 'MADHUSUDAN BANJARA' from Line 613 in data\today1.txt
# ✅ Extracted: 'NABINA KHADKA' from Line 614 in data\today1.txt
# ✅ Extracted: 'SUSMITA BHOLAN' from Line 615 in data\today1.txt
# ✅ Extracted: 'MANOJ KUMAR RAY' from Line 616 in data\today1.txt
# ✅ Extracted: 'RADHIKA DAHAL' from Line 617 in data\today1.txt
# ✅ Extracted: 'DIPESH GHALAN' from Line 618 in data\today1.txt
# ✅ Extracted: 'BIGYATA C CHAULAGAIN' from Line 619 in data\today1.txt
# ✅ Extracted: 'SANTOSH THAKURI' from Line 620 in data\today1.txt
# ✅ Extracted: 'ASMITA SHRESTHA' from Line 621 in data\today1.txt
# ✅ Extracted: 'NISHA SYANGTAN' from Line 622 in data\today1.txt
# ✅ Extracted: 'KAMALA ADHIKARI' from Line 623 in data\today1.txt
# ✅ Extracted: 'SUNITA GURUNG' from Line 624 in data\today1.txt
# ✅ Extracted: 'AMRIT KHADKA' from Line 625 in data\today1.txt
# ✅ Extracted: 'KARNA BAHADUR LAMA' from Line 626 in data\today1.txt
# ✅ Extracted: 'HIRA BAHADUR SUNAR' from Line 627 in data\today1.txt
# ✅ Extracted: 'PARBATI GHALAN' from Line 628 in data\today1.txt
# ✅ Extracted: 'SAGAR LAMICHHANE' from Line 629 in data\today1.txt
# ✅ Extracted: 'SABINA LAMICHHANE' from Line 630 in data\today1.txt
# ✅ Extracted: 'BUDDHA F UDHYOG' from Line 631 in data\today1.txt
# ✅ Extracted: 'ANUJA PAUDEL' from Line 632 in data\today1.txt
# ✅ Extracted: 'SUJITA MOKTAN' from Line 633 in data\today1.txt
# ✅ Extracted: 'DEVI MAYA GHIMIRE' from Line 634 in data\today1.txt
# ✅ Extracted: 'SHOM PRASAD DAHAL' from Line 635 in data\today1.txt
# ✅ Extracted: 'SUMAN KHATIODA' from Line 636 in data\today1.txt
# ✅ Extracted: 'GOMA  PATHAK' from Line 637 in data\today1.txt
# ✅ Extracted: 'BHUMIRAJ DARJI' from Line 638 in data\today1.txt
# ✅ Extracted: 'DEEPA THAPA' from Line 639 in data\today1.txt
# ✅ Extracted: 'MAN BAHADUR RAI' from Line 640 in data\today1.txt
# ✅ Extracted: 'ROHIT KUMAR KARKI' from Line 641 in data\today1.txt
# ✅ Extracted: 'DURGA MAYA GRANJA' from Line 642 in data\today1.txt
# ✅ Extracted: 'JAMUNA KUMARI KARKI' from Line 643 in data\today1.txt
# ✅ Extracted: 'TULASHA K KHADKA' from Line 644 in data\today1.txt
# ✅ Extracted: 'SUSHAN SHARMA' from Line 645 in data\today1.txt
# ✅ Extracted: 'TAK NARAN SHRESTHA' from Line 646 in data\today1.txt
# ✅ Extracted: 'SANDIP GAIRE' from Line 647 in data\today1.txt
# ✅ Extracted: 'SHANKAR BARAL' from Line 648 in data\today1.txt
# ✅ Extracted: 'SARAN KUMAR SHRETHA' from Line 649 in data\today1.txt
# ✅ Extracted: 'DHAN KUMARI CHHETRI' from Line 650 in data\today1.txt
# ✅ Extracted: 'KISAN MAHAT' from Line 651 in data\today1.txt
# ✅ Extracted: 'URMILA A DHAKAL' from Line 652 in data\today1.txt
# ✅ Extracted: 'ANIL NEPALI' from Line 653 in data\today1.txt
# ✅ Extracted: 'SETIMAYA GHIMIRE' from Line 654 in data\today1.txt
# ✅ Extracted: 'SITA PAUDEL' from Line 655 in data\today1.txt
# ✅ Extracted: 'PREM RAWAT KSHETRI' from Line 656 in data\today1.txt
# ✅ Extracted: 'DILLI BAHADUR THAPA' from Line 657 in data\today1.txt
# ✅ Extracted: 'SABINA KHAN' from Line 658 in data\today1.txt
# ✅ Extracted: 'GANGA KUMARI BIST' from Line 659 in data\today1.txt
# ✅ Extracted: 'BINITA SUNAR' from Line 660 in data\today1.txt
# ✅ Extracted: 'KOMAL BUDHA CHHETRI' from Line 661 in data\today1.txt
# ✅ Extracted: 'AARATI SUBEDI' from Line 662 in data\today1.txt
# ✅ Extracted: 'SUNITA THARU' from Line 663 in data\today1.txt
# ✅ Extracted: 'SAIRUN KHAN' from Line 664 in data\today1.txt
# ✅ Extracted: 'BHADRA LAL PUN' from Line 665 in data\today1.txt
# ✅ Extracted: 'RAJESH KUMAR THARU' from Line 666 in data\today1.txt
# ✅ Extracted: 'SUSHILA CHAUDHARY' from Line 667 in data\today1.txt
# ✅ Extracted: 'ABDUL MUTALIB KHAN' from Line 668 in data\today1.txt
# ✅ Extracted: 'GITA KAWAR' from Line 669 in data\today1.txt
# ✅ Extracted: 'SUJIT KIRANA PASAL' from Line 670 in data\today1.txt
# ✅ Extracted: 'SUBI KHAN' from Line 671 in data\today1.txt
# ✅ Extracted: 'MAYA DAVI KURMI' from Line 672 in data\today1.txt
# ✅ Extracted: 'MOHAMMAD NAKI KHAN' from Line 673 in data\today1.txt
# ✅ Extracted: 'SHANTA SINGH' from Line 674 in data\today1.txt
# ✅ Extracted: 'KRISHNA N THAKUR' from Line 675 in data\today1.txt
# ✅ Extracted: 'INDRANIL GHOSH' from Line 676 in data\today1.txt
# ✅ Extracted: 'DIB BAHADUR GURUNG' from Line 677 in data\today1.txt
# ✅ Extracted: 'SHYAM SHRESTHA' from Line 678 in data\today1.txt
# ✅ Extracted: 'SANDHYA CHHETRI' from Line 679 in data\today1.txt
# ✅ Extracted: 'BINITA MALLA' from Line 680 in data\today1.txt
# ✅ Extracted: 'SANGITA N RUCHAL' from Line 681 in data\today1.txt
# ✅ Extracted: 'URBA MAGAR' from Line 682 in data\today1.txt
# ✅ Extracted: 'AMRIT RAJ NEPAL' from Line 683 in data\today1.txt
# ✅ Extracted: 'SUSHMA BISHWOKARMA' from Line 684 in data\today1.txt
# ✅ Extracted: 'SAMA PRAVIN' from Line 685 in data\today1.txt
# ✅ Extracted: 'DOL BAHADUR RAJ' from Line 686 in data\today1.txt
# ✅ Extracted: 'SUSHIL POKHREL' from Line 687 in data\today1.txt
# ✅ Extracted: 'PADAM BAHADUR PUN' from Line 688 in data\today1.txt
# ✅ Extracted: 'SARADA PANTHI' from Line 689 in data\today1.txt
# ✅ Extracted: 'ABDUL SABOOR KHAN' from Line 690 in data\today1.txt
# ✅ Extracted: 'KISHAN THAPA' from Line 691 in data\today1.txt
# ✅ Extracted: 'AMIT K BAJRACHARYA' from Line 692 in data\today1.txt
# ✅ Extracted: 'BISHNU PAUDEL' from Line 693 in data\today1.txt
# ✅ Extracted: 'SURISHA B.K.' from Line 694 in data\today1.txt
# ✅ Extracted: 'KALPANA NATH YOGI' from Line 695 in data\today1.txt
# ✅ Extracted: 'SHARADA  SUBEDI' from Line 696 in data\today1.txt
# ✅ Extracted: 'KRISHNA K THAPA' from Line 697 in data\today1.txt
# ✅ Extracted: 'GARIMA SHAHI' from Line 698 in data\today1.txt
# ✅ Extracted: 'DIPA GHARTI' from Line 699 in data\today1.txt
# ✅ Extracted: 'KALPANA K MALLA' from Line 700 in data\today1.txt
# ✅ Extracted: 'MANISHA YOGI' from Line 701 in data\today1.txt
# ✅ Extracted: 'KARUNA KHATRI' from Line 702 in data\today1.txt
# ✅ Extracted: 'PREM BAHADUR BASNET' from Line 703 in data\today1.txt
# ✅ Extracted: 'DEBENDRA J ADHIKARI' from Line 704 in data\today1.txt
# ✅ Extracted: 'KUNCHHANG D THING' from Line 705 in data\today1.txt
# ✅ Extracted: 'BIRENDRA P PANUHAR' from Line 706 in data\today1.txt
# ✅ Extracted: 'SITA K CHAUDHARY' from Line 707 in data\today1.txt
# ✅ Extracted: 'LAXMINARAYAN CHAU' from Line 708 in data\today1.txt
# ✅ Extracted: 'SHYAM K CHAUDHARY' from Line 709 in data\today1.txt
# ✅ Extracted: 'URMILA K CHAUDHARY' from Line 710 in data\today1.txt
# ✅ Extracted: 'ARUNA CHAUDHARY' from Line 711 in data\today1.txt
# ✅ Extracted: 'ARJUN KUMAR YADAV' from Line 712 in data\today1.txt
# ✅ Extracted: 'FULKANTI D CHAUDHARY' from Line 713 in data\today1.txt
# ✅ Extracted: 'AADARSH CHAUDHARY' from Line 714 in data\today1.txt
# ✅ Extracted: 'KRISHANA MUKHIYA' from Line 715 in data\today1.txt
# ✅ Extracted: 'SUVASH MOKTAN' from Line 716 in data\today1.txt
# ✅ Extracted: 'SUBI KHATUN' from Line 717 in data\today1.txt
# ✅ Extracted: 'RAJAN K CHAUDHARY' from Line 718 in data\today1.txt
# ✅ Extracted: 'NIKSHITA ADHIKARI' from Line 719 in data\today1.txt
# ✅ Extracted: 'NABYA CHAUDHARY' from Line 720 in data\today1.txt
# ✅ Extracted: 'SHREEJANA K CHAU' from Line 721 in data\today1.txt
# ✅ Extracted: 'AARAV CHAUDHARY' from Line 722 in data\today1.txt
# ✅ Extracted: 'UMA B.K' from Line 723 in data\today1.txt
# ✅ Extracted: 'ALISHA CHAUDHARY' from Line 724 in data\today1.txt
# ✅ Extracted: 'JAY B CHAUDHARY' from Line 725 in data\today1.txt
# ✅ Extracted: 'DIVYANSHI CHAUDHARY' from Line 726 in data\today1.txt
# ✅ Extracted: 'MANBI CHAUDHARY' from Line 727 in data\today1.txt
# ✅ Extracted: 'AARAV CHAUDHARY' from Line 728 in data\today1.txt
# ✅ Extracted: 'KHUSHBU CHAUDHARY' from Line 729 in data\today1.txt
# ✅ Extracted: 'RABINDRA CHAUDHARY' from Line 730 in data\today1.txt
# ✅ Extracted: 'TAPESHWAR CHAUDHARY' from Line 731 in data\today1.txt
# ✅ Extracted: 'RAM P CHAUDHARY' from Line 732 in data\today1.txt
# ✅ Extracted: 'AAFRIN KHATUN' from Line 733 in data\today1.txt
# ✅ Extracted: 'SPANDAN SHIWAKOTI' from Line 734 in data\today1.txt
# ✅ Extracted: 'BINAY K CHAUDHARY' from Line 735 in data\today1.txt
# ✅ Extracted: 'DIKCHHYA BASTOLA' from Line 736 in data\today1.txt
# ✅ Extracted: 'SURESH P CHAUDHARY' from Line 737 in data\today1.txt
# ✅ Extracted: 'UWALAL CHAUDHARY' from Line 738 in data\today1.txt
# ✅ Extracted: 'CHANDRA KALA THAPA' from Line 739 in data\today1.txt
# ✅ Extracted: 'AMBHU KUMAR YADAV' from Line 740 in data\today1.txt
# ✅ Extracted: 'SAMIR CHAUDHARY' from Line 741 in data\today1.txt
# ✅ Extracted: 'NIRMAL CHAUDHARY' from Line 742 in data\today1.txt
# ✅ Extracted: 'KOSHILA K CHAUDHARY' from Line 743 in data\today1.txt
# ✅ Extracted: 'JARINA K CHAUDHARY' from Line 744 in data\today1.txt
# ✅ Extracted: 'SHANTI K CHAUDHARY' from Line 745 in data\today1.txt
# ✅ Extracted: 'KARTIK CHAUDHARY' from Line 746 in data\today1.txt
# ✅ Extracted: 'RINA CHAUDHARY' from Line 747 in data\today1.txt
# ✅ Extracted: 'DILLI B HAMAL' from Line 748 in data\today1.txt
# ✅ Extracted: 'AJAY KUMAR SAH' from Line 749 in data\today1.txt
# ✅ Extracted: 'ANITA THARUNI' from Line 750 in data\today1.txt
# ✅ Extracted: 'PHURDIKI SHERPA' from Line 751 in data\today1.txt
# ✅ Extracted: 'RANJANA THATAL' from Line 752 in data\today1.txt
# ✅ Extracted: 'BIGYATA KHATRI' from Line 753 in data\today1.txt
# ...
# ✅ Extracted: 'ASMITA J BHATTARAI' from Line 1229 in data\today2.txt
# ✅ Extracted: 'MANISHA NEUPANE' from Line 1230 in data\today2.txt
# ✅ Extracted: 'ALISHA THAPA' from Line 1231 in data\today2.txt
# ✅ Extracted: 'OM MAYA SHRESTHA' from Line 1232 in data\today2.txt
# ✅ Extracted: 'HARK BAHADUR MALASI' from Line 1233 in data\today2.txt
# ✅ Extracted: 'SARADA BIST' from Line 1234 in data\today2.txt
# ✅ Extracted: 'HIKMAT BAHADUR BIST' from Line 1235 in data\today2.txt
# ✅ Extracted: 'MAHA SINGH KADAYAT' from Line 1236 in data\today2.txt
# ✅ Extracted: 'KUNTI DEVI SAUD' from Line 1237 in data\today2.txt
# ✅ Extracted: 'SITA AAUJI' from Line 1238 in data\today2.txt
# ✅ Extracted: 'HARISH NEPALI' from Line 1239 in data\today2.txt
# ✅ Extracted: 'BISNA AAUJI' from Line 1240 in data\today2.txt
# ✅ Extracted: 'AARTI KUMARI SAH' from Line 1241 in data\today2.txt
# ✅ Extracted: 'MALA KUMARI SAH' from Line 1242 in data\today2.txt
# ✅ Extracted: 'SANJAY KUMAR THAPA' from Line 1243 in data\today2.txt
# ✅ Extracted: 'ROSHAN BIJ BHANDAR' from Line 1244 in data\today2.txt
# ✅ Extracted: 'MANJU K GURAGAI' from Line 1245 in data\today2.txt
# ✅ Extracted: 'SIJAN KARKI' from Line 1246 in data\today2.txt
# ✅ Extracted: 'MANJU B.K.' from Line 1247 in data\today2.txt
# ✅ Extracted: 'MANOJ KUMAR  PRADHAN' from Line 1248 in data\today2.txt
# ✅ Extracted: 'PAMPHA KUMARI THAPA' from Line 1249 in data\today2.txt
# ✅ Extracted: 'TARA KUMARI YADAV' from Line 1250 in data\today2.txt
# ✅ Extracted: 'DUJ KUMARI RAI' from Line 1251 in data\today2.txt
# ✅ Extracted: 'CHADANI RAI' from Line 1252 in data\today2.txt
# ✅ Extracted: 'HIMMAT B CHOUDHARY' from Line 1253 in data\today2.txt
# ✅ Extracted: 'NIRUTA THAPA' from Line 1254 in data\today2.txt
# ✅ Extracted: 'RESHMA CHAUDHARY' from Line 1255 in data\today2.txt
# ✅ Extracted: 'GITA B.C. GIRI' from Line 1256 in data\today2.txt
# ✅ Extracted: 'GITA BUDHA' from Line 1257 in data\today2.txt
# ✅ Extracted: 'JANAKI K ACHARYA' from Line 1258 in data\today2.txt
# ✅ Extracted: 'DEBENDRA B B.K.' from Line 1259 in data\today2.txt
# ✅ Extracted: 'SARMILA SHAHI' from Line 1260 in data\today2.txt
# ✅ Extracted: 'OM PRASAD SHARMA' from Line 1261 in data\today2.txt
# ✅ Extracted: 'CHANDRA SHING THAPA' from Line 1262 in data\today2.txt
# ✅ Extracted: 'RAJENDRA P ACHARYA' from Line 1263 in data\today2.txt
# ✅ Extracted: 'SOMAN SHAHI' from Line 1264 in data\today2.txt
# ✅ Extracted: 'BHIMRAJ CHALAUNE' from Line 1265 in data\today2.txt
# ✅ Extracted: 'SARMILA BUDHA' from Line 1266 in data\today2.txt
# ✅ Extracted: 'MUKTI RAM SHARMA' from Line 1267 in data\today2.txt
# ✅ Extracted: 'SIRJANA RIJAL' from Line 1268 in data\today2.txt
# ✅ Extracted: 'HARILAL SUNAR' from Line 1269 in data\today2.txt
# ✅ Extracted: 'KAVI DUTTA NEUPANE' from Line 1270 in data\today2.txt
# ✅ Extracted: 'ANISH RANA' from Line 1271 in data\today2.txt
# ✅ Extracted: 'PREM BAHADUR RAI' from Line 1272 in data\today2.txt
# ✅ Extracted: 'ABISHA KARKI' from Line 1273 in data\today2.txt
# ✅ Extracted: 'LAXMI ADHIKARI' from Line 1274 in data\today2.txt
# ✅ Extracted: 'SAUMYA KHANAL' from Line 1275 in data\today2.txt
# ✅ Extracted: 'RAJENDRA D GHIMIRE' from Line 1276 in data\today2.txt
# ✅ Extracted: 'SONAM THING' from Line 1277 in data\today2.txt
# ✅ Extracted: 'PRADIP THAPA' from Line 1278 in data\today2.txt
# ✅ Extracted: 'BIJ BAHADUR YONJAN' from Line 1279 in data\today2.txt
# ✅ Extracted: 'SURENDRA B. GHIMIRE' from Line 1280 in data\today2.txt
# ✅ Extracted: 'SAKUNTALA T. MAGAR' from Line 1281 in data\today2.txt
# ✅ Extracted: 'BAL K SHRESTHA' from Line 1282 in data\today2.txt
# ✅ Extracted: 'ANU THAPA' from Line 1283 in data\today2.txt
# ✅ Extracted: 'PURAN REGMI' from Line 1284 in data\today2.txt
# ✅ Extracted: 'PUSPANJALI K.C.' from Line 1285 in data\today2.txt
# ✅ Extracted: 'PUKAR RANA' from Line 1286 in data\today2.txt
# ✅ Extracted: 'BRIJBIHARI  KURMI' from Line 1287 in data\today2.txt
# ✅ Extracted: 'BIKRAM PRASAD MURAU' from Line 1288 in data\today2.txt
# ✅ Extracted: 'SANDEEP KU CHAUDHARY' from Line 1289 in data\today2.txt
# ✅ Extracted: 'ALINA BK' from Line 1290 in data\today2.txt
# ✅ Extracted: 'REWANTA BD BASNET' from Line 1291 in data\today2.txt
# ✅ Extracted: 'MOHAN KUMAR JIREL' from Line 1292 in data\today2.txt
# ✅ Extracted: 'RAJAN KUMAR DONG' from Line 1293 in data\today2.txt
# ✅ Extracted: 'JUNUN BHLON' from Line 1294 in data\today2.txt
# ✅ Extracted: 'ANJU TAMANG' from Line 1295 in data\today2.txt
# ✅ Extracted: 'PREM KUNWAR' from Line 1296 in data\today2.txt
# ✅ Extracted: 'AMRITA LAMA TAMANG' from Line 1297 in data\today2.txt
# ✅ Extracted: 'ANIL POKHREL' from Line 1298 in data\today2.txt
# ✅ Extracted: 'MINA REGMI' from Line 1299 in data\today2.txt
# ✅ Extracted: 'SUMAN KARKI' from Line 1300 in data\today2.txt
# ✅ Extracted: 'SHANTI BALAMI' from Line 1301 in data\today2.txt
# ✅ Extracted: 'TEJ KUMARI SHRESTHA' from Line 1302 in data\today2.txt
# ✅ Extracted: 'TEK BAHADUR MAGAR' from Line 1303 in data\today2.txt
# ✅ Extracted: 'NAWARAJ POUDEL' from Line 1304 in data\today2.txt
# ✅ Extracted: 'NITU THAPA' from Line 1305 in data\today2.txt
# ✅ Extracted: 'DASRAM D THARU' from Line 1306 in data\today2.txt
# ✅ Extracted: 'KESAV BUDHA' from Line 1307 in data\today2.txt
# ✅ Extracted: 'SWECHHA GHIMIRE' from Line 1308 in data\today2.txt
# ✅ Extracted: 'SALLAN BEHENA' from Line 1309 in data\today2.txt
# ✅ Extracted: 'S.A.GAI B TATHA' from Line 1310 in data\today2.txt
# ✅ Extracted: 'SADANANDA BAHUN' from Line 1311 in data\today2.txt
# ✅ Extracted: 'SUNILA SHRESTHA' from Line 1312 in data\today2.txt
# ✅ Extracted: 'CHETAN KUMAR SHARMA' from Line 1313 in data\today2.txt
# ✅ Extracted: 'RAJ KRISHNA  VERMA' from Line 1314 in data\today2.txt
# ✅ Extracted: 'KAMAL B ADHIKARI' from Line 1315 in data\today2.txt
# ✅ Extracted: 'DEBINDRA SUNAR BK' from Line 1316 in data\today2.txt
# ✅ Extracted: 'HUM BAHADUR ROKA' from Line 1317 in data\today2.txt
# ✅ Extracted: 'SARMILA MAHARA' from Line 1318 in data\today2.txt
# ✅ Extracted: 'MANJU DEULA PODE' from Line 1319 in data\today2.txt
# ✅ Extracted: 'JAMUNA P THAPA' from Line 1320 in data\today2.txt
# ✅ Extracted: 'DURGA DEVI BASNET' from Line 1321 in data\today2.txt
# ✅ Extracted: 'SHIBAHARI KATHAYAT' from Line 1322 in data\today2.txt
# ✅ Extracted: 'BHOJA NANDA RAI' from Line 1323 in data\today2.txt
# ✅ Extracted: 'SHYAM KHADKA' from Line 1324 in data\today2.txt
# ✅ Extracted: 'NILU GURUNG  OLI' from Line 1325 in data\today2.txt
# ✅ Extracted: 'SABIN KARKI' from Line 1326 in data\today2.txt
# ✅ Extracted: 'SHER B MAHARJAN' from Line 1327 in data\today2.txt
# ✅ Extracted: 'NARAYAN B PRADHAN' from Line 1328 in data\today2.txt
# ✅ Extracted: 'RAJAN CHAUDHARY' from Line 1329 in data\today2.txt
# ✅ Extracted: 'JHALAK RAJ PAUDEL' from Line 1330 in data\today2.txt
# ✅ Extracted: 'BALARAM BHANDARI' from Line 1331 in data\today2.txt
# ✅ Extracted: 'SANTOSHI REGMI' from Line 1332 in data\today2.txt
# ✅ Extracted: 'BISHAL PAUDEL' from Line 1333 in data\today2.txt
# ✅ Extracted: 'LAXMI ACHARYA' from Line 1334 in data\today2.txt
# ✅ Extracted: 'ROSAN DANGI' from Line 1335 in data\today2.txt
# ✅ Extracted: 'NUMA SUBEDI' from Line 1336 in data\today2.txt
# ✅ Extracted: 'SAMJHANA DAHAL' from Line 1337 in data\today2.txt
# ✅ Extracted: 'ANITA SUNAR' from Line 1338 in data\today2.txt
# ✅ Extracted: 'KSHITIJ K.C.' from Line 1339 in data\today2.txt
# ✅ Extracted: 'ATIT KC' from Line 1340 in data\today2.txt
# ✅ Extracted: 'SANGITA PAUDEL' from Line 1341 in data\today2.txt
# ✅ Extracted: 'ANANDA K.C' from Line 1342 in data\today2.txt
# ✅ Extracted: 'SABITRA OLI KHATRI' from Line 1343 in data\today2.txt
# ✅ Extracted: 'GOMA OLI' from Line 1344 in data\today2.txt
# ✅ Extracted: 'KUMARI B DEVKOTA' from Line 1345 in data\today2.txt
# ✅ Extracted: 'SUSHILA DEVI KARKI' from Line 1346 in data\today2.txt
# ✅ Extracted: 'CHANDRA BAHADUR OLI' from Line 1347 in data\today2.txt
# ✅ Extracted: 'DIPA BHANDARI' from Line 1348 in data\today2.txt
# ✅ Extracted: 'YUBA RAJ GHIMIRE' from Line 1349 in data\today2.txt
# ✅ Extracted: 'BHAN RAJ NEUPANE' from Line 1350 in data\today2.txt
# ✅ Extracted: 'RUJA K BISHWKARMA' from Line 1351 in data\today2.txt
# ✅ Extracted: 'YASODA DHAKAL' from Line 1352 in data\today2.txt
# ✅ Extracted: 'CHEDI KUMARI DHIMAL' from Line 1353 in data\today2.txt
# ✅ Extracted: 'DIPENDRA B SHAHI' from Line 1354 in data\today2.txt
# ✅ Extracted: 'MAN B SHRESTHA' from Line 1355 in data\today2.txt
# ✅ Extracted: 'KAMAL P DHUNGANA' from Line 1356 in data\today2.txt
# ✅ Extracted: 'SUSMITA SINGH' from Line 1357 in data\today2.txt
# ✅ Extracted: 'DIPAK SHRESTHA' from Line 1358 in data\today2.txt
# ✅ Extracted: 'DINESH SHAHI' from Line 1359 in data\today2.txt
# ✅ Extracted: 'KSHITIZ KHANAL' from Line 1360 in data\today2.txt
# ✅ Extracted: 'DINESH SINGH DHAT' from Line 1361 in data\today2.txt
# ✅ Extracted: 'LILARAM UPADHYAYA' from Line 1362 in data\today2.txt
# ✅ Extracted: 'MILEE  SHRESTHA' from Line 1363 in data\today2.txt
# ✅ Extracted: 'DEVKALA CHAPAGAI' from Line 1364 in data\today2.txt
# ✅ Extracted: 'KRISHNA RAJ K.C.' from Line 1365 in data\today3.txt
# ✅ Extracted: 'SUJITA KUSWAR' from Line 1366 in data\today3.txt
# ✅ Extracted: 'SHOVA ADHIKARI' from Line 1367 in data\today3.txt
# ✅ Extracted: 'MOHAN KAMATI' from Line 1368 in data\today3.txt
# ✅ Extracted: 'MANI KUMAR GURUNG' from Line 1369 in data\today3.txt
# ✅ Extracted: 'MADAN KUMAL' from Line 1370 in data\today3.txt
# ✅ Extracted: 'TUK BAHADUR THAPA' from Line 1371 in data\today3.txt
# ✅ Extracted: 'DAMODAR GAUTAM' from Line 1372 in data\today3.txt
# ✅ Extracted: 'THANESHWOR NEUPANE' from Line 1373 in data\today3.txt
# ✅ Extracted: 'KHUSHI R CHAUDHARI' from Line 1374 in data\today3.txt
# ✅ Extracted: 'MAN KUMAR BANIYA' from Line 1375 in data\today3.txt
# ✅ Extracted: 'ASHMA SHARMA' from Line 1376 in data\today3.txt
# ✅ Extracted: 'GOVINDA KHATRI' from Line 1377 in data\today3.txt
# ✅ Extracted: 'LAL BAHADUR THARU' from Line 1378 in data\today3.txt
# ✅ Extracted: 'MAYARAM JAISHI' from Line 1379 in data\today3.txt
# ✅ Extracted: 'JASMINA  JOSHI' from Line 1380 in data\today3.txt
# ✅ Extracted: 'OM M CONSTRUCTION' from Line 1381 in data\today3.txt
# ✅ Extracted: 'NEW ANUSHKA MASALA' from Line 1382 in data\today3.txt
# ✅ Extracted: 'DINESH SUBEDI' from Line 1383 in data\today3.txt
# ✅ Extracted: 'SARMILA BUDHATHOKI' from Line 1384 in data\today3.txt
# ✅ Extracted: 'JEETENDRA YADAV' from Line 1385 in data\today3.txt
# ✅ Extracted: 'OMKAR YADAV' from Line 1386 in data\today3.txt
# ✅ Extracted: 'SHARADA B K' from Line 1387 in data\today3.txt
# ✅ Extracted: 'MANISHA GHARTI' from Line 1388 in data\today3.txt
# ✅ Extracted: 'SUNITA BUDHATHOKI' from Line 1389 in data\today3.txt
# ✅ Extracted: 'BIRENDRA THARU' from Line 1390 in data\today3.txt
# ✅ Extracted: 'DEV RAJ UPRETI' from Line 1391 in data\today3.txt
# ✅ Extracted: 'NIRMALA CHAUDHARY' from Line 1392 in data\today3.txt
# ✅ Extracted: 'BAL BAHADUR SHAHI' from Line 1393 in data\today3.txt
# ✅ Extracted: 'PRADIP BHATT' from Line 1394 in data\today3.txt
# ✅ Extracted: 'KAMALA JOSHI BHATT' from Line 1395 in data\today3.txt
# ✅ Extracted: 'RITA  TIMRAKAR' from Line 1396 in data\today3.txt
# ✅ Extracted: 'ASHA LAMA' from Line 1397 in data\today3.txt
# ✅ Extracted: 'DEV BAHADUR THAPA' from Line 1398 in data\today3.txt
# ✅ Extracted: 'SUMITRA BASTOLA' from Line 1399 in data\today3.txt
# ✅ Extracted: 'DINISHA NAKAL' from Line 1400 in data\today3.txt
# ✅ Extracted: 'MANISHA ADHIKARI' from Line 1401 in data\today3.txt
# ✅ Extracted: 'KIRAN KUMARI SADA' from Line 1402 in data\today3.txt
# ✅ Extracted: 'MANISHA KHADAYAT' from Line 1403 in data\today3.txt
# ✅ Extracted: 'KALAWATI K BHANDARI' from Line 1404 in data\today3.txt
# ✅ Extracted: 'AMBER BAHADUR  ROKAYA' from Line 1405 in data\today3.txt
# ✅ Extracted: 'DHURBA PRASAD  NEUPANE' from Line 1406 in data\today3.txt
# ✅ Extracted: 'IZHAR  ALAM' from Line 1407 in data\today3.txt
# ✅ Extracted: 'SHARMILA PARAJULI' from Line 1408 in data\today3.txt
# ✅ Extracted: 'UMA KUMARI BISTA' from Line 1409 in data\today3.txt
# ✅ Extracted: 'DHANA KUMARI SHARMA' from Line 1410 in data\today3.txt
# ✅ Extracted: 'MAHENDRA P CHAU' from Line 1411 in data\today3.txt
# ✅ Extracted: 'ASHOK KUMAR  SHAHI' from Line 1412 in data\today3.txt
# ✅ Extracted: 'JANAKI SHAHI' from Line 1413 in data\today3.txt
# ✅ Extracted: 'SURAJ KUMAR SAH' from Line 1414 in data\today3.txt
# ✅ Extracted: 'BADRI N SARDAR' from Line 1415 in data\today3.txt
# ✅ Extracted: 'NISHANTA LUITEL' from Line 1416 in data\today3.txt
# ✅ Extracted: 'RABINA RAI' from Line 1417 in data\today3.txt
# ✅ Extracted: 'LALIT B BHUJEL' from Line 1418 in data\today3.txt
# ✅ Extracted: 'SHERAP LAMA' from Line 1419 in data\today3.txt
# ✅ Extracted: 'BABITA SHRESTHA' from Line 1420 in data\today3.txt
# ✅ Extracted: 'LOK BAHADUR GURUNG' from Line 1421 in data\today3.txt
# ✅ Extracted: 'MOHAN PUN' from Line 1422 in data\today3.txt
# ✅ Extracted: 'PANCHAKANYA S KRISHI' from Line 1423 in data\today3.txt
# ✅ Extracted: 'SAMBRIDHHA D KRISHI' from Line 1424 in data\today3.txt
# ✅ Extracted: 'RAMESH JHA' from Line 1425 in data\today3.txt
# ✅ Extracted: 'MAHESH JOSHI' from Line 1426 in data\today3.txt
# ✅ Extracted: 'DEVKANTA MEHTA' from Line 1427 in data\today3.txt
# ✅ Extracted: 'PRAMOD CHAUDHARY' from Line 1428 in data\today3.txt
# ✅ Extracted: 'BARSHA PUJARA' from Line 1429 in data\today3.txt
# ✅ Extracted: 'NAW RAJ  PANDEY' from Line 1430 in data\today3.txt
# ✅ Extracted: 'PUJA BHATT' from Line 1431 in data\today3.txt
# ✅ Extracted: 'BHUPENDRA DHUNGANA' from Line 1432 in data\today3.txt
# ✅ Extracted: 'BIBEK ADHIKARI' from Line 1433 in data\today3.txt
# ✅ Extracted: 'ROJAN BUDHA MAGAR' from Line 1434 in data\today3.txt
# ✅ Extracted: 'ASMITA TAMANG' from Line 1435 in data\today3.txt
# ✅ Extracted: 'LILA MAYA TAMANG' from Line 1436 in data\today3.txt
# ✅ Extracted: 'UMA DEVI KARKI' from Line 1437 in data\today3.txt
# ✅ Extracted: 'AMISH KHANAL' from Line 1438 in data\today3.txt
# ✅ Extracted: 'ANIL D.C' from Line 1439 in data\today3.txt
# ✅ Extracted: 'RADHE SHYAM THAKUR' from Line 1440 in data\today3.txt
# ✅ Extracted: 'SUMAN KC' from Line 1441 in data\today3.txt
# ✅ Extracted: 'TOP BAHADUR SHAHI' from Line 1442 in data\today3.txt
# ✅ Extracted: 'RAJAN PHUYAL' from Line 1443 in data\today3.txt
# ✅ Extracted: 'RADHIKA SAUD' from Line 1444 in data\today3.txt
# ✅ Extracted: 'MAHESH THAMI MAGAR' from Line 1445 in data\today3.txt
# ✅ Extracted: 'NAMRATA BARUWAL' from Line 1446 in data\today3.txt
# ✅ Extracted: 'LAXMI ADHIKARI' from Line 1447 in data\today3.txt
# ✅ Extracted: 'KAILO LOHAR' from Line 1448 in data\today3.txt
# ✅ Extracted: 'RABINDRA K THARU' from Line 1449 in data\today3.txt
# ✅ Extracted: 'MADHAV DEV ACHARYA' from Line 1450 in data\today3.txt
# ✅ Extracted: 'CHETAN DAS  TIMSINA' from Line 1451 in data\today3.txt
# ✅ Extracted: 'NISHA REULE' from Line 1452 in data\today3.txt
# ✅ Extracted: 'MANSUWA THAPA' from Line 1453 in data\today3.txt
# ✅ Extracted: 'NITU DHAKAL' from Line 1454 in data\today3.txt
# ✅ Extracted: 'APSANA KHATUN' from Line 1455 in data\today3.txt
# ✅ Extracted: 'RAKESH GURUNG' from Line 1456 in data\today3.txt
# ✅ Extracted: 'SABINA GURUNG' from Line 1457 in data\today3.txt
# ✅ Extracted: 'SUN BAHADUR TAMANG' from Line 1458 in data\today3.txt
# ✅ Extracted: 'CHANDRA R CHAUDHARY' from Line 1459 in data\today3.txt
# ✅ Extracted: 'MINA KUMARI DARUKA' from Line 1460 in data\today3.txt
# ✅ Extracted: 'DIL BAHADUR  SHRESTHA' from Line 1461 in data\today3.txt
# ✅ Extracted: 'NABIN SHRESTHA' from Line 1462 in data\today3.txt
# ✅ Extracted: 'RAMESH K POKHREL' from Line 1463 in data\today3.txt
# ✅ Extracted: 'RAJU TAMANG' from Line 1464 in data\today3.txt
# ✅ Extracted: 'POST B PUDASAINI' from Line 1465 in data\today3.txt
# ✅ Extracted: 'CHANDAN KUMAR GUPTA' from Line 1466 in data\today3.txt
# ✅ Extracted: 'KRISHNA KUMAR GUPTA' from Line 1467 in data\today3.txt
# ✅ Extracted: 'GOKARNA  KUNWAR' from Line 1468 in data\today3.txt
# ✅ Extracted: 'MADHU SUDAN  ARYAL' from Line 1469 in data\today3.txt
# ✅ Extracted: 'ABHISHEK K SINGH' from Line 1470 in data\today3.txt
# ✅ Extracted: 'SURESH  GOTHE' from Line 1471 in data\today3.txt
# ✅ Extracted: 'DURGA  BHANDARI' from Line 1472 in data\today3.txt
# ✅ Extracted: 'SHANTI PRASAD  RIJAL' from Line 1473 in data\today3.txt
#
# ✅ Extraction complete. Found 1473 entries from 4 files.
# ✅ CSV created: combined_output.csv

# %%
import pandas as pd
import os

# Ask user if they have multiple HCS files
multiple_files = input("Do you have multiple HCS files to process? (yes/no): ").lower().strip()

all_hcs_data = []

if multiple_files == 'yes':
    # Ask for multiple file paths
    hcs_paths = []
    while True:
        path = input("Please enter the path to an HCS file (html/xls) (or 'done' to finish): ")
        if path.lower() == 'done':
            break
        if os.path.exists(path):
            hcs_paths.append(path)
        else:
            print("Error: The file does not exist. Please check the path and try again.")

    if not hcs_paths:
        print("Error: No valid files provided. Exiting.")
    else:
        # Process each HCS file
        for hcs_path in hcs_paths:
            try:
                hcs = pd.read_csv('hcs_path')
#                 with open(hcs_path, 'r', encoding='utf-8') as file:
#                     html_content = file.read()
#                 hcs_list = pd.read_html(html_content)
#                 hcs = hcs_list[0]
                
#                 # Making first row as column
#                 hcs.columns = hcs.iloc[0]  # Set the first row as column names
#                 hcs = hcs[1:].reset_index(drop=True)  # Remove the first row and reset index
#                 all_hcs_data.append(hcs)
#                 print(f"✅ Successfully processed: {hcs_path}")
            except Exception as e:
                print(f"⚠️ Error processing {hcs_path}: {str(e)}")

        # Combine all dataframes
        if all_hcs_data:
            combined_hcs = pd.concat(all_hcs_data, ignore_index=True)
            print(f"\n✅ Combined {len(all_hcs_data)} HCS files")
            print("First few rows of combined data:")
            print(combined_hcs.head())
        else:
            print("No data was successfully processed.")

else:
    # Single file processing
    hcs_path = input("Please enter the path to your HCS file (html/xls): ")

    # Check if the file exists
    if not os.path.exists(hcs_path):
        print("Error: The file does not exist. Please check the path and try again.")
    else:
        try:
            with open(hcs_path, 'r', encoding='utf-8') as file:
                html_content = file.read()
            hcs_list = pd.read_html(html_content)
            hcs = hcs_list[0]

            # Making first row as column
            hcs.columns = hcs.iloc[0]  # Set the first row as column names
            hcs = hcs[1:].reset_index(drop=True)  # Remove the first row and reset index
            
            print(f"\n✅ Successfully processed: {hcs_path}")
            print("First few rows of data:")
            print(hcs.head())
            print(f"Total rows {len(hcs)}")
        except Exception as e:
            print(f"⚠️ Error processing {hcs_path}: {str(e)}")

# %%
# Update of multiple hcs file

import pandas as pd
import os

# Ask user if they have multiple HCS files
multiple_files = input("Do you have multiple HCS files to process? (yes/no): ").lower().strip()

all_hcs_data = []

def process_file(file_path):
    """Process a single file (CSV, XLS, or HTML) and return a DataFrame."""
    try:
        if file_path.endswith('.csv'):
            df = pd.read_csv(file_path)
        elif file_path.endswith(('.xls', '.xlsx')):
            df = pd.read_excel(file_path)
        elif file_path.endswith('.html'):
            with open(file_path, 'r', encoding='utf-8') as file:
                html_content = file.read()
            df_list = pd.read_html(html_content)
            df = df_list[0]
            # Set first row as column names for HTML files
            df.columns = df.iloc[0]
            df = df[1:].reset_index(drop=True)
        else:
            raise ValueError("Unsupported file format. Use CSV, XLS/XLSX, or HTML.")
        return df
    except Exception as e:
        print(f"⚠️ Error processing {file_path}: {str(e)}")
        return None

if multiple_files == 'yes':
    # Ask for multiple file paths
    hcs_paths = []
    while True:
        path = input("Please enter the path to an HCS file (html/xls/csv) (or 'done' to finish): ")
        if path.lower() == 'done':
            break
        if os.path.exists(path):
            hcs_paths.append(path)
        else:
            print("Error: The file does not exist. Please check the path and try again.")

    if not hcs_paths:
        print("Error: No valid files provided. Exiting.")
    else:
        # Process each HCS file
        for hcs_path in hcs_paths:
            hcs = process_file(hcs_path)
            if hcs is not None:
                all_hcs_data.append(hcs)
                print(f"✅ Successfully processed: {hcs_path}")

        # Combine all dataframes
        if all_hcs_data:
            combined_hcs = pd.concat(all_hcs_data, ignore_index=True)
            print(f"\n✅ Combined {len(all_hcs_data)} HCS files")
            print("First few rows of combined data:")
            print(combined_hcs.head())
            # Option to save
            save = input("Would you like to save the combined data to a CSV file? (yes/no): ").lower().strip()
            if save == 'yes':
                output_path = input("Enter the output file path (e.g., output.csv): ")
                combined_hcs.to_csv(output_path, index=False)
                print(f"✅ Saved to {output_path}")
        else:
            print("No data was successfully processed.")

else:
    # Single file processing
    hcs_path = input("Please enter the path to your HCS file (html/xls/csv): ")
    if not os.path.exists(hcs_path):
        print("Error: The file does not exist. Please check the path and try again.")
    else:
        hcs = process_file(hcs_path)
        if hcs is not None:
            print(f"\n✅ Successfully processed: {hcs_path}")
            print("First few rows of data:")
            print(hcs.head())
            print(f"Total rows: {len(hcs)}")
            # Option to save
            save = input("Would you like to save the data to a CSV file? (yes/no): ").lower().strip()
            if save == 'yes':
                output_path = input("Enter the output file path (e.g., output.csv): ")
                hcs.to_csv(output_path, index=False)
                print(f"✅ Saved to {output_path}")
# Out:
# Do you have multiple HCS files to process? (yes/no): no
# Please enter the path to your HCS file (html/xls/csv): today2.xlsx
#
# ✅ Successfully processed: today2.xlsx
# First few rows of data:
#    ISSTYPE       CARD_NUMBER             CRDH_NAME         ATM_ACCT  \
# 0  REPLACE  4753960000746392           IJAJ HUSSEN  414701406417018
# 1  REPLACE  4753960000742094  TEJLAXMI RAJBHANDARI  210200053905015
# 2  REPLACE  4753960000742102  PURNA BAHADUR KHADGI  210201108720016
# 3  REPLACE  4753960000742193    SUKRA P. RANJITKAR  210001312381019
# 4  REPLACE  4753960000742219        BISHNU B SINGH  726105035139015
#
#      ISS_DATE  EXPIR_DATE  CARD_ID
# 0  2025-03-24  2029-03-24  1308014
# 1  2025-03-24  2029-03-24  1306670
# 2  2025-03-24  2029-03-24  1306671
# 3  2025-03-24  2029-03-24  1306678
# 4  2025-03-24  2029-03-24  1306680
# Total rows: 237
# Would you like to save the data to a CSV file? (yes/no): no

# %%
import os
import re
import pandas as pd

def normalize_name(name):
    """Normalize a name by converting to uppercase, removing extra spaces, and splitting into components"""
    if pd.isna(name) or name == "NaN":
        return {"first": "", "middle": "", "surname": ""}
    # Remove extra spaces and convert to uppercase
    name = " ".join(name.split()).upper()
    parts = name.split()
    
    if len(parts) == 1:
        return {"first": parts[0], "middle": "", "surname": ""}
    elif len(parts) == 2:
        return {"first": parts[0], "middle": "", "surname": parts[1]}
    else:
        return {"first": parts[0], "middle": " ".join(parts[1:-1]), "surname": parts[-1]}

# --- Process Extracted Names ---
multiple_txt_files = input("Do you have multiple text files for name extraction? (yes/no): ").lower().strip()
all_extracted_names = []
line_number = 0

if multiple_txt_files == 'yes':
    txt_paths = []
    while True:
        path = input("Please enter the path to a text file (or 'done' to finish): ")
        if path.lower() == 'done':
            break
        if os.path.exists(path):
            txt_paths.append(path)
        else:
            print("Error: File does not exist.")

    for txt_path in txt_paths:
        with open(txt_path, 'r', encoding='utf-8') as txt_file:
            for line in txt_file:
                line_number += 1
                matches = re.findall(r'NPR\s{0,4}([A-Z][A-Z.\s]+)', line)
                if matches:
                    for match in matches:
                        all_extracted_names.append(match.strip())
                else:
                    all_extracted_names.append("NaN")
else:
    txt_path = input("Please enter the path to your text file: ")
    if os.path.exists(txt_path):
        with open(txt_path, 'r', encoding='utf-8') as txt_file:
            for line in txt_file:
                line_number += 1
                matches = re.findall(r'NPR\s{0,4}([A-Z][A-Z.\s]+)', line)
                if matches:
                    for match in matches:
                        all_extracted_names.append(match.strip())
                else:
                    all_extracted_names.append("NaN")

extracted_df = pd.DataFrame({'EXTRACTED_NAME': all_extracted_names})

# --- Process HCS Files ---
multiple_hcs_files = input("Do you have multiple HCS files to process? (yes/no): ").lower().strip()
all_hcs_data = []

if multiple_hcs_files == 'yes':
    hcs_paths = []
    while True:
        path = input("Please enter the path to an HCS file (or 'done' to finish): ")
        if path.lower() == 'done':
            break
        if os.path.exists(path):
            hcs_paths.append(path)

    for hcs_path in hcs_paths:
        with open(hcs_path, 'r', encoding='utf-8') as file:
            hcs_list = pd.read_html(file.read())
            hcs = hcs_list[0]
            hcs.columns = hcs.iloc[0]
            hcs = hcs[1:].reset_index(drop=True)
            all_hcs_data.append(hcs)
    
    hcs_df = pd.concat(all_hcs_data, ignore_index=True)
else:
    hcs_path = input("Please enter the path to your HCS file: ")
    if os.path.exists(hcs_path):
        with open(hcs_path, 'r', encoding='utf-8') as file:
            hcs_list = pd.read_html(file.read())
            hcs_df = hcs_list[0]
            hcs_df.columns = hcs_df.iloc[0]
            hcs_df = hcs_df[1:].reset_index(drop=True)

# --- Name Matching ---
# Assume HCS has a column called 'NAME' - adjust this based on your actual column name
hcs_name_col = 'E_NAME'  # Replace with actual column name if different

# Normalize names
hcs_df['norm'] = hcs_df[hcs_name_col].apply(normalize_name)
extracted_df['norm'] = extracted_df['EXTRACTED_NAME'].apply(normalize_name)

# Create matching keys
hcs_df['match_key'] = hcs_df['norm'].apply(lambda x: f"{x['first']}|{x['middle']}|{x['surname']}")
extracted_df['match_key'] = extracted_df['norm'].apply(lambda x: f"{x['first']}|{x['middle']}|{x['surname']}")

# Use extracted_df as base (smaller set)
matched_df = extracted_df.merge(
    hcs_df,
    how='left',
    on='match_key',
    suffixes=('_extracted', '_hcs')
)

# Add extracted name to matched rows
matched_df['MATCHED_EXTRACTED_NAME'] = matched_df['EXTRACTED_NAME']

# Clean up: keep only necessary columns and remove unmatched rows
final_df = matched_df.dropna(subset=[hcs_name_col])  # Drop rows where HCS data wasn't matched
final_df = final_df.drop(columns=['norm_extracted', 'norm_hcs', 'match_key'])

# Results
print(f"\nOriginal HCS rows: {len(hcs_df)}")
print(f"Extracted names: {len(extracted_df)}")
print(f"Final matched rows: {len(final_df)}")
print("\nFirst few rows of final DataFrame:")
print(final_df.head())

# Optionally save to CSV
final_df.to_csv('matched_output.csv', index=False)
print("✅ Results saved to 'matched_output.csv'")
# Out:
# Do you have multiple text files for name extraction? (yes/no): yes
# Please enter the path to a text file (or 'done' to finish): data/today.txt
# Please enter the path to a text file (or 'done' to finish): data\today1.txt
# Please enter the path to a text file (or 'done' to finish): data\today2.txt
# Please enter the path to a text file (or 'done' to finish): data\today3.txt
# Please enter the path to a text file (or 'done' to finish): done

# %%
# find duplication in HCS file
# After creating hcs_df but before merging
duplicate_hcs_names = hcs_df['match_key'].duplicated(keep=False)
print(f"Number of HCS rows with duplicate match_keys: {duplicate_hcs_names.sum()}")
print(f"Unique match_keys in HCS with duplicates: {hcs_df[duplicate_hcs_names]['match_key'].nunique()}")

# After the merge, before final_df
print(f"Rows in matched_df before dropping NaN: {len(matched_df)}")
duplicate_matches = matched_df['match_key'].duplicated(keep=False)
print(f"Number of matched rows with duplicate match_keys: {duplicate_matches.sum()}")
# Out:
# Number of HCS rows with duplicate match_keys: 65
# Unique match_keys in HCS with duplicates: 31
# Rows in matched_df before dropping NaN: 820
# Number of matched rows with duplicate match_keys: 45

# %%
import os
import re
import pandas as pd

def normalize_name(name):
    """Normalize a name by converting to uppercase, removing extra spaces, and splitting into components"""
    if pd.isna(name) or name == "NaN":
        return {"first": "", "middle": "", "surname": ""}
    name = " ".join(name.split()).upper()
    parts = name.split()
    if len(parts) == 1:
        return {"first": parts[0], "middle": "", "surname": ""}
    elif len(parts) == 2:
        return {"first": parts[0], "middle": "", "surname": parts[1]}
    else:
        return {"first": parts[0], "middle": " ".join(parts[1:-1]), "surname": parts[-1]}

# --- Process Extracted Names ---
multiple_txt_files = input("Do you have multiple text files for name extraction? (yes/no): ").lower().strip()
all_extracted_names = []
line_number = 0

if multiple_txt_files == 'yes':
    txt_paths = []
    while True:
        path = input("Please enter the path to a text file (or 'done' to finish): ")
        if path.lower() == 'done':
            break
        if os.path.exists(path):
            txt_paths.append(path)
    for txt_path in txt_paths:
        with open(txt_path, 'r', encoding='utf-8') as txt_file:
            for line in txt_file:
                line_number += 1
                matches = re.findall(r'NPR\s{0,4}([A-Z][A-Z.\s]+)', line)
                if matches:
                    for match in matches:
                        all_extracted_names.append(match.strip())
                else:
                    all_extracted_names.append("NaN")
else:
    txt_path = input("Please enter the path to your text file: ")
    if os.path.exists(txt_path):
        with open(txt_path, 'r', encoding='utf-8') as txt_file:
            for line in txt_file:
                line_number += 1
                matches = re.findall(r'NPR\s{0,4}([A-Z][A-Z.\s]+)', line)
                if matches:
                    for match in matches:
                        all_extracted_names.append(match.strip())
                else:
                    all_extracted_names.append("NaN")

extracted_df = pd.DataFrame({'EXTRACTED_NAME': all_extracted_names})

# --- Process HCS Files ---
multiple_hcs_files = input("Do you have multiple HCS files to process? (yes/no): ").lower().strip()
all_hcs_data = []

if multiple_hcs_files == 'yes':
    hcs_paths = []
    while True:
        path = input("Please enter the path to an HCS file (or 'done' to finish): ")
        if path.lower() == 'done':
            break
        if os.path.exists(path):
            hcs_paths.append(path)
    for hcs_path in hcs_paths:
        with open(hcs_path, 'r', encoding='utf-8') as file:
            hcs_list = pd.read_html(file.read())
            hcs = hcs_list[0]
            hcs.columns = hcs.iloc[0]
            hcs = hcs[1:].reset_index(drop=True)
            all_hcs_data.append(hcs)
    hcs_df = pd.concat(all_hcs_data, ignore_index=True)
else:
    hcs_path = input("Please enter the path to your HCS file: ")
    if os.path.exists(hcs_path):
        with open(hcs_path, 'r', encoding='utf-8') as file:
            hcs_list = pd.read_html(file.read())
            hcs_df = hcs_list[0]
            hcs_df.columns = hcs_df.iloc[0]
            hcs_df = hcs_df[1:].reset_index(drop=True)

# --- Name Matching ---
hcs_name_col = 'E_NAME'  # Adjust if different
account_col = 'ACCOUNT'  # Adjust if different

# Normalize names
hcs_df['norm'] = hcs_df[hcs_name_col].apply(normalize_name)
extracted_df['norm'] = extracted_df['EXTRACTED_NAME'].apply(normalize_name)

# Create matching keys
hcs_df['match_key'] = hcs_df['norm'].apply(lambda x: f"{x['first']}|{x['middle']}|{x['surname']}")
extracted_df['match_key'] = extracted_df['norm'].apply(lambda x: f"{x['first']}|{x['middle']}|{x['surname']}")

# Merge with extracted_df as base
matched_df = extracted_df.merge(
    hcs_df,
    how='left',
    on='match_key',
    suffixes=('_extracted', '_hcs')
)
matched_df['MATCHED_EXTRACTED_NAME'] = matched_df['EXTRACTED_NAME']

# Keep only rows with HCS matches
matched_df = matched_df.dropna(subset=[hcs_name_col])

# --- Deduplication and Splitting ---
# Identify duplicates based on EXTRACTED_NAME and ACCOUNT
duplicate_mask = matched_df.duplicated(subset=['EXTRACTED_NAME', account_col], keep=False)

# Create two DataFrames
duplicate_df = matched_df[duplicate_mask].drop(columns=['norm_extracted', 'norm_hcs', 'match_key'])
unique_df = matched_df[~duplicate_mask].drop(columns=['norm_extracted', 'norm_hcs', 'match_key'])

# Results
print(f"\nOriginal HCS rows: {len(hcs_df)}")
print(f"Extracted names: {len(extracted_df)}")
print(f"Matched rows before splitting: {len(matched_df)}")
print(f"Rows with duplicate ACCOUNT and EXTRACTED_NAME: {len(duplicate_df)}")
print(f"Unique or non-duplicate rows: {len(unique_df)}")

print("\nFirst few rows of duplicate DataFrame:")
print(duplicate_df.head())
print("\nFirst few rows of unique DataFrame:")
print(unique_df.head())

# Save to CSV
duplicate_df.to_csv('duplicate_matches.csv', index=False)
unique_df.to_csv('unique_matches.csv', index=False)
print("✅ Results saved to 'duplicate_matches.csv' and 'unique_matches.csv'")
# Out:
# Do you have multiple text files for name extraction? (yes/no): yes
# Please enter the path to a text file (or 'done' to finish): data\216.txt
# Please enter the path to a text file (or 'done' to finish): data\227.txt
# Please enter the path to a text file (or 'done' to finish): done
# Do you have multiple HCS files to process? (yes/no): no
# Please enter the path to your HCS file: data\hcs.xls
#
# Original HCS rows: 2464
# Extracted names: 796
# Matched rows before splitting: 819
# Rows with duplicate ACCOUNT and EXTRACTED_NAME: 26
# Unique or non-duplicate rows: 793
#
# First few rows of duplicate DataFrame:
#          EXTRACTED_NAME CAR_CODE               PAN               E_NAME  \
# 5         SAMJHANA LAMA  1299092  4753960000713095        SAMJHANA LAMA
# 6         SAMJHANA LAMA  1302149  4753960000722740        SAMJHANA LAMA
# 8   PREM BAHADUR NEPALI  1298371  4753960000709929  PREM BAHADUR NEPALI
# 9   PREM BAHADUR NEPALI  1298738  4753960000715140  PREM BAHADUR NEPALI
# 10  PREM BAHADUR NEPALI  1299094  4753960000713111  PREM BAHADUR NEPALI
#
#              ACCOUNT STATUS             EXPIRYDATE MATCHED_EXTRACTED_NAME
# 5   0508901382009013      5  2/17/2029 11:29:50 AM          SAMJHANA LAMA
# 6   0210305309301011      5   3/3/2029 10:12:42 AM          SAMJHANA LAMA
# 8   0726205559770019      5  2/17/2029 11:28:00 AM    PREM BAHADUR NEPALI
# 9   0720905560036019      5  2/17/2029 11:29:00 AM    PREM BAHADUR NEPALI
# 10  0317703015150013      5  2/17/2029 11:29:50 AM    PREM BAHADUR NEPALI
#
# First few rows of unique DataFrame:
#        EXTRACTED_NAME CAR_CODE               PAN              E_NAME  \
# 0      DURGA KALIKOTA  1299066  4753960000713046      DURGA KALIKOTA
# 1  PRAKASH BUDHATHOKI  1299067  4753960000713053  PRAKASH BUDHATHOKI
# 2   SHESH MANI PAUDEL  1299089  4753960000713061   SHESH MANI PAUDEL
# 3    RAGHUNATH  JOSHI  1299090  4753960000713079     RAGHUNATH JOSHI
# 4    PRABIN KHATIWADA  1299091  4753960000713087    PRABIN KHATIWADA
#
#             ACCOUNT STATUS             EXPIRYDATE MATCHED_EXTRACTED_NAME
# 0  0509101754534011      5  2/17/2029 11:29:47 AM         DURGA KALIKOTA
# 1  0919801433127012      5  2/17/2029 11:29:47 AM     PRAKASH BUDHATHOKI
# 2  0416101439919019      5  2/17/2029 11:29:50 AM      SHESH MANI PAUDEL
# 3  0100200391375018      5  2/17/2029 11:29:50 AM       RAGHUNATH  JOSHI
# 4  0100202004881019      5  2/17/2029 11:29:50 AM       PRABIN KHATIWADA
# ✅ Results saved to 'duplicate_matches.csv' and 'unique_matches.csv'

# %%
import os
import re
import pandas as pd

def normalize_name(name):
    """Normalize a name by converting to uppercase, removing extra spaces, and splitting into components"""
    if pd.isna(name) or name == "NaN":
        return {"first": "", "middle": "", "surname": ""}
    name = " ".join(name.split()).upper()
    parts = name.split()
    if len(parts) == 1:
        return {"first": parts[0], "middle": "", "surname": ""}
    elif len(parts) == 2:
        return {"first": parts[0], "middle": "", "surname": parts[1]}
    else:
        return {"first": parts[0], "middle": " ".join(parts[1:-1]), "surname": parts[-1]}

# --- Process Extracted Names ---
multiple_txt_files = input("Do you have multiple text files for name extraction? (yes/no): ").lower().strip()
all_extracted_names = []
line_number = 0

if multiple_txt_files == 'yes':
    txt_paths = []
    while True:
        path = input("Please enter the path to a text file (or 'done' to finish): ")
        if path.lower() == 'done':
            break
        if os.path.exists(path):
            txt_paths.append(path)
    for txt_path in txt_paths:
        with open(txt_path, 'r', encoding='utf-8') as txt_file:
            for line in txt_file:
                line_number += 1
                matches = re.findall(r'NPR\s{0,4}([A-Z][A-Z.\s]+)', line)
                if matches:
                    for match in matches:
                        all_extracted_names.append(match.strip())
                else:
                    all_extracted_names.append("NaN")
else:
    txt_path = input("Please enter the path to your text file: ")
    if os.path.exists(txt_path):
        with open(txt_path, 'r', encoding='utf-8') as txt_file:
            for line in txt_file:
                line_number += 1
                matches = re.findall(r'NPR\s{0,4}([A-Z][A-Z.\s]+)', line)
                if matches:
                    for match in matches:
                        all_extracted_names.append(match.strip())
                else:
                    all_extracted_names.append("NaN")

extracted_df = pd.DataFrame({'EXTRACTED_NAME': all_extracted_names})

# --- Process HCS Files ---
multiple_hcs_files = input("Do you have multiple HCS files to process? (yes/no): ").lower().strip()
all_hcs_data = []

if multiple_hcs_files == 'yes':
    hcs_paths = []
    while True:
        path = input("Please enter the path to an HCS file (or 'done' to finish): ")
        if path.lower() == 'done':
            break
        if os.path.exists(path):
            hcs_paths.append(path)
    for hcs_path in hcs_paths:
        with open(hcs_path, 'r', encoding='utf-8') as file:
            hcs_list = pd.read_html(file.read())
            hcs = hcs_list[0]
            hcs.columns = hcs.iloc[0]
            hcs = hcs[1:].reset_index(drop=True)
            all_hcs_data.append(hcs)
    hcs_df = pd.concat(all_hcs_data, ignore_index=True)
else:
    hcs_path = input("Please enter the path to your HCS file: ")
    if os.path.exists(hcs_path):
        with open(hcs_path, 'r', encoding='utf-8') as file:
            hcs_list = pd.read_html(file.read())
            hcs_df = hcs_list[0]
            hcs_df.columns = hcs_df.iloc[0]
            hcs_df = hcs_df[1:].reset_index(drop=True)

# --- Name Matching ---
hcs_name_col = 'E_NAME'  # HCS Name (E_Name)
account_col = 'ACCOUNT'  # Adjust if different

# Normalize names
hcs_df['norm'] = hcs_df[hcs_name_col].apply(normalize_name)
extracted_df['norm'] = extracted_df['EXTRACTED_NAME'].apply(normalize_name)

# Create matching keys
hcs_df['match_key'] = hcs_df['norm'].apply(lambda x: f"{x['first']}|{x['middle']}|{x['surname']}")
extracted_df['match_key'] = extracted_df['norm'].apply(lambda x: f"{x['first']}|{x['middle']}|{x['surname']}")

# Merge with extracted_df as base
matched_df = extracted_df.merge(
    hcs_df,
    how='left',
    on='match_key',
    suffixes=('_extracted', '_hcs')
)
matched_df['MATCHED_EXTRACTED_NAME'] = matched_df['EXTRACTED_NAME']

# Keep only rows with HCS matches
matched_df = matched_df.dropna(subset=[hcs_name_col])

# --- Deduplication and Splitting ---
duplicate_mask = matched_df.duplicated(subset=['EXTRACTED_NAME', account_col], keep=False)
duplicate_df = matched_df[duplicate_mask].drop(columns=['norm_extracted', 'norm_hcs', 'match_key'])
unique_df = matched_df[~duplicate_mask].drop(columns=['norm_extracted', 'norm_hcs', 'match_key'])

# --- Compare E_Name (HCS NAME) and EXTRACTED_NAME in unique_df ---
# Function to check length considering spaces as characters
def check_length_match(row):
    hcs_name = str(row[hcs_name_col]) if pd.notna(row[hcs_name_col]) else ""
    extracted_name = str(row['EXTRACTED_NAME']) if pd.notna(row['EXTRACTED_NAME']) else ""
    return len(hcs_name) == len(extracted_name)

# Apply length check
unique_df['length_match'] = unique_df.apply(check_length_match, axis=1)

# Split into matched and mismatched based on length
mismatched_df = unique_df[~unique_df['length_match']].drop(columns=['length_match'])
matched_unique_df = unique_df[unique_df['length_match']].drop(columns=['length_match'])

# Results
print(f"\nOriginal HCS rows: {len(hcs_df)}")
print(f"Extracted names: {len(extracted_df)}")
print(f"Matched rows before splitting: {len(matched_df)}")
print(f"Rows with duplicate ACCOUNT and EXTRACTED_NAME: {len(duplicate_df)}")
print(f"Unique or non-duplicate rows: {len(unique_df)}")
print(f"Rows with mismatched lengths in unique_df: {len(mismatched_df)}")
print(f"Rows with matched lengths in unique_df: {len(matched_unique_df)}")

print("\nFirst few rows of duplicate DataFrame:")
print(duplicate_df.head())
print("\nFirst few rows of mismatched DataFrame:")
print(mismatched_df.head())
print("\nFirst few rows of matched unique DataFrame:")
print(matched_unique_df.head())

# Save to CSV
duplicate_df.to_csv('duplicate_matches.csv', index=False)
mismatched_df.to_csv('mismatched_lengths.csv', index=False)
matched_unique_df.to_csv('matched_unique.csv', index=False)
print("✅ Results saved to 'duplicate_matches.csv', 'mismatched_lengths.csv', and 'matched_unique.csv'")
# Out:
# Do you have multiple text files for name extraction? (yes/no): yes
# Please enter the path to a text file (or 'done' to finish): data\216.txt
# Please enter the path to a text file (or 'done' to finish): data\227.txt
# Please enter the path to a text file (or 'done' to finish): done
# Do you have multiple HCS files to process? (yes/no): no
# Please enter the path to your HCS file: data\hcs.xls
#
# Original HCS rows: 2464
# Extracted names: 796
# Matched rows before splitting: 819
# Rows with duplicate ACCOUNT and EXTRACTED_NAME: 26
# Unique or non-duplicate rows: 793
# Rows with mismatched lengths in unique_df: 37
# Rows with matched lengths in unique_df: 756
#
# First few rows of duplicate DataFrame:
#          EXTRACTED_NAME CAR_CODE               PAN               E_NAME  \
# 5         SAMJHANA LAMA  1299092  4753960000713095        SAMJHANA LAMA
# 6         SAMJHANA LAMA  1302149  4753960000722740        SAMJHANA LAMA
# 8   PREM BAHADUR NEPALI  1298371  4753960000709929  PREM BAHADUR NEPALI
# 9   PREM BAHADUR NEPALI  1298738  4753960000715140  PREM BAHADUR NEPALI
# 10  PREM BAHADUR NEPALI  1299094  4753960000713111  PREM BAHADUR NEPALI
#
#              ACCOUNT STATUS             EXPIRYDATE MATCHED_EXTRACTED_NAME
# 5   0508901382009013      5  2/17/2029 11:29:50 AM          SAMJHANA LAMA
# 6   0210305309301011      5   3/3/2029 10:12:42 AM          SAMJHANA LAMA
# 8   0726205559770019      5  2/17/2029 11:28:00 AM    PREM BAHADUR NEPALI
# 9   0720905560036019      5  2/17/2029 11:29:00 AM    PREM BAHADUR NEPALI
# 10  0317703015150013      5  2/17/2029 11:29:50 AM    PREM BAHADUR NEPALI
#
# First few rows of mismatched DataFrame:
#        EXTRACTED_NAME CAR_CODE               PAN           E_NAME  \
# 3    RAGHUNATH  JOSHI  1299090  4753960000713079  RAGHUNATH JOSHI
# 45      KUMAR  SHERPA  1298393  4753960000713459     KUMAR SHERPA
# 69   MANISHA  DEVKOTA  1298437  4753960000713681  MANISHA DEVKOTA
# 113    BABURAM  NEPAL  1298519  4753960000714101    BABURAM NEPAL
# 169       RENU  JOSHI  1298630  4753960000714648       RENU JOSHI
#
#               ACCOUNT STATUS             EXPIRYDATE MATCHED_EXTRACTED_NAME
# 3    0100200391375018      5  2/17/2029 11:29:50 AM       RAGHUNATH  JOSHI
# 45   0601100357337013      5  2/17/2029 11:28:05 AM          KUMAR  SHERPA
# 69   0509201030652015      5  2/17/2029 11:28:12 AM       MANISHA  DEVKOTA
# 113  0424501455580012      5  2/17/2029 11:28:24 AM         BABURAM  NEPAL
# 169  0209500025415035      5  2/17/2029 11:28:41 AM            RENU  JOSHI
#
# First few rows of matched unique DataFrame:
#        EXTRACTED_NAME CAR_CODE               PAN              E_NAME  \
# 0      DURGA KALIKOTA  1299066  4753960000713046      DURGA KALIKOTA
# 1  PRAKASH BUDHATHOKI  1299067  4753960000713053  PRAKASH BUDHATHOKI
# 2   SHESH MANI PAUDEL  1299089  4753960000713061   SHESH MANI PAUDEL
# 4    PRABIN KHATIWADA  1299091  4753960000713087    PRABIN KHATIWADA
# 7     YUNISHA SAPKOTA  1299093  4753960000713103     YUNISHA SAPKOTA
#
#             ACCOUNT STATUS             EXPIRYDATE MATCHED_EXTRACTED_NAME
# 0  0509101754534011      5  2/17/2029 11:29:47 AM         DURGA KALIKOTA
# 1  0919801433127012      5  2/17/2029 11:29:47 AM     PRAKASH BUDHATHOKI
# 2  0416101439919019      5  2/17/2029 11:29:50 AM      SHESH MANI PAUDEL
# 4  0100202004881019      5  2/17/2029 11:29:50 AM       PRABIN KHATIWADA
# 7  0508901222532011      5  2/17/2029 11:29:50 AM        YUNISHA SAPKOTA
# ✅ Results saved to 'duplicate_matches.csv', 'mismatched_lengths.csv', and 'matched_unique.csv'

# %%
sample.columns
# Out:
# Index(['ISSTYPE', 'CARD_NUMBER', 'CRDH_NAME', 'ATM_ACCT', 'ISS_DATE',
#        'EXPIR_DATE', 'CARD_ID'],
#       dtype='object')

# %%
import os
import re
import pandas as pd
from datetime import datetime, timedelta

def normalize_name(name):
    """Normalize a name by converting to uppercase, removing extra spaces, and splitting into components"""
    if pd.isna(name) or name == "NaN":
        return {"first": "", "middle": "", "surname": ""}
    name = " ".join(name.split()).upper()
    parts = name.split()
    if len(parts) == 1:
        return {"first": parts[0], "middle": "", "surname": ""}
    elif len(parts) == 2:
        return {"first": parts[0], "middle": "", "surname": parts[1]}
    else:
        return {"first": parts[0], "middle": " ".join(parts[1:-1]), "surname": parts[-1]}

# --- Process Extracted Names ---
multiple_txt_files = input("Do you have multiple text files for name extraction? (yes/no): ").lower().strip()
all_extracted_names = []
line_number = 0

if multiple_txt_files == 'yes':
    txt_paths = []
    while True:
        path = input("Please enter the path to a text file (or 'done' to finish): ")
        if path.lower() == 'done':
            break
        if os.path.exists(path):
            txt_paths.append(path)
    for txt_path in txt_paths:
        with open(txt_path, 'r', encoding='utf-8') as txt_file:
            for line in txt_file:
                line_number += 1
                matches = re.findall(r'NPR\s{0,4}([A-Z][A-Z.\s]+)', line)
                if matches:
                    for match in matches:
                        all_extracted_names.append(match.strip())
                else:
                    all_extracted_names.append("NaN")
else:
    txt_path = input("Please enter the path to your text file: ")
    if os.path.exists(txt_path):
        with open(txt_path, 'r', encoding='utf-8') as txt_file:
            for line in txt_file:
                line_number += 1
                matches = re.findall(r'NPR\s{0,4}([A-Z][A-Z.\s]+)', line)
                if matches:
                    for match in matches:
                        all_extracted_names.append(match.strip())
                else:
                    all_extracted_names.append("NaN")

extracted_df = pd.DataFrame({'EXTRACTED_NAME': all_extracted_names})

# --- Process HCS Files ---
multiple_hcs_files = input("Do you have multiple HCS files to process? (yes/no): ").lower().strip()
all_hcs_data = []

if multiple_hcs_files == 'yes':
    hcs_paths = []
    while True:
        path = input("Please enter the path to an HCS file (or 'done' to finish): ")
        if path.lower() == 'done':
            break
        if os.path.exists(path):
            hcs_paths.append(path)
    for hcs_path in hcs_paths:
        with open(hcs_path, 'r', encoding='utf-8') as file:
            hcs_list = pd.read_html(file.read())
            hcs = hcs_list[0]
            hcs.columns = hcs.iloc[0]
            hcs = hcs[1:].reset_index(drop=True)
            all_hcs_data.append(hcs)
    hcs_df = pd.concat(all_hcs_data, ignore_index=True)
else:
    hcs_path = input("Please enter the path to your HCS file: ")
    if os.path.exists(hcs_path):
        with open(hcs_path, 'r', encoding='utf-8') as file:
            hcs_list = pd.read_html(file.read())
            hcs_df = hcs_list[0]
            hcs_df.columns = hcs_df.iloc[0]
            hcs_df = hcs_df[1:].reset_index(drop=True)

# --- Name Matching ---
hcs_name_col = 'E_NAME'  # HCS Name (E_Name)
account_col = 'ACCOUNT'  # ATM_ACCT
pan_col = 'PAN'  # CARD_NUMBER (adjust if different)
card_code_col = 'CAR_CODE'  # CARD_ID (adjust if different)
expiry_date_col = 'EXPIRYDATE'  # EXPIR_DATE (adjust if different)

# Normalize names
hcs_df['norm'] = hcs_df[hcs_name_col].apply(normalize_name)
extracted_df['norm'] = extracted_df['EXTRACTED_NAME'].apply(normalize_name)

# Create matching keys
hcs_df['match_key'] = hcs_df['norm'].apply(lambda x: f"{x['first']}|{x['middle']}|{x['surname']}")
extracted_df['match_key'] = extracted_df['norm'].apply(lambda x: f"{x['first']}|{x['middle']}|{x['surname']}")

# Merge with extracted_df as base
matched_df = extracted_df.merge(
    hcs_df,
    how='left',
    on='match_key',
    suffixes=('_extracted', '_hcs')
)
matched_df['MATCHED_EXTRACTED_NAME'] = matched_df['EXTRACTED_NAME']

# Keep only rows with HCS matches
matched_df = matched_df.dropna(subset=[hcs_name_col])

# --- Deduplication and Splitting ---
duplicate_mask = matched_df.duplicated(subset=['EXTRACTED_NAME', account_col], keep=False)
duplicate_df = matched_df[duplicate_mask].drop(columns=['norm_extracted', 'norm_hcs', 'match_key'])
unique_df = matched_df[~duplicate_mask].drop(columns=['norm_extracted', 'norm_hcs', 'match_key'])

# --- Compare E_Name and EXTRACTED_NAME in unique_df ---
def check_length_match(row):
    hcs_name = str(row[hcs_name_col]) if pd.notna(row[hcs_name_col]) else ""
    extracted_name = str(row['EXTRACTED_NAME']) if pd.notna(row['EXTRACTED_NAME']) else ""
    return len(hcs_name) == len(extracted_name)

unique_df['length_match'] = unique_df.apply(check_length_match, axis=1)
mismatched_df = unique_df[~unique_df['length_match']].drop(columns=['length_match'])
matched_unique_df = unique_df[unique_df['length_match']].drop(columns=['length_match'])

# --- Generate Excel Output for mismatched_df ---
# Define output columns
output_columns = ['ISSTYPE', 'CARD_NUMBER', 'CRDH_NAME', 'ATM_ACCT', 'ISS_DATE', 'EXPIR_DATE', 'CARD_ID']

# Create output DataFrame
output_df = pd.DataFrame(columns=output_columns)

# Populate values
output_df['ISSTYPE'] = 'new'
output_df['CARD_NUMBER'] = mismatched_df[pan_col]  # PAN from HCS
output_df['CRDH_NAME'] = mismatched_df['EXTRACTED_NAME']  # Extracted name
output_df['ATM_ACCT'] = mismatched_df[account_col]  # Account from HCS

# Handle EXPIR_DATE from mismatched_df
output_df['EXPIR_DATE'] = pd.to_datetime(mismatched_df[expiry_date_col]).dt.strftime('%Y-%m-%d')

# Calculate ISS_DATE (EXPIR_DATE - 4 years, year only)
output_df['ISS_DATE'] = (pd.to_datetime(mismatched_df[expiry_date_col]) - timedelta(days=4*365)).dt.strftime('%Y')

# CARD_ID from CARD_CODE
output_df['CARD_ID'] = mismatched_df.get(card_code_col, '')  # Empty string if not present

# Results
print(f"\nOriginal HCS rows: {len(hcs_df)}")
print(f"Extracted names: {len(extracted_df)}")
print(f"Matched rows before splitting: {len(matched_df)}")
print(f"Rows with duplicate ACCOUNT and EXTRACTED_NAME: {len(duplicate_df)}")
print(f"Unique or non-duplicate rows: {len(unique_df)}")
print(f"Rows with mismatched lengths in unique_df: {len(mismatched_df)}")
print(f"Rows with matched lengths in unique_df: {len(matched_unique_df)}")

print("\nFirst few rows of Excel output DataFrame:")
print(output_df.head())

# Save to Excel
output_df.to_excel('mismatched_output.xlsx', index=False)
duplicate_df.to_csv('duplicate_matches.csv', index=False)
mismatched_df.to_csv('mismatched_lengths.csv', index=False)
matched_unique_df.to_csv('matched_unique.csv', index=False)
print("✅ Results saved to 'mismatched_output.xlsx', 'duplicate_matches.csv', 'mismatched_lengths.csv', and 'matched_unique.csv'")
# Out:
# Do you have multiple text files for name extraction? (yes/no): yes
# Please enter the path to a text file (or 'done' to finish): data\216.txt
# Please enter the path to a text file (or 'done' to finish): data\227.txt
# Please enter the path to a text file (or 'done' to finish): done
# Do you have multiple HCS files to process? (yes/no): data\hcs.xls
# Please enter the path to your HCS file: data\hcs.xls
#
# Original HCS rows: 2464
# Extracted names: 796
# Matched rows before splitting: 819
# Rows with duplicate ACCOUNT and EXTRACTED_NAME: 26
# Unique or non-duplicate rows: 793
# Rows with mismatched lengths in unique_df: 37
# Rows with matched lengths in unique_df: 756
#
# First few rows of Excel output DataFrame:
#     ISSTYPE       CARD_NUMBER         CRDH_NAME          ATM_ACCT ISS_DATE  \
# 3       NaN  4753960000713079  RAGHUNATH  JOSHI  0100200391375018     2025
# 45      NaN  4753960000713459     KUMAR  SHERPA  0601100357337013     2025
# 69      NaN  4753960000713681  MANISHA  DEVKOTA  0509201030652015     2025
# 113     NaN  4753960000714101    BABURAM  NEPAL  0424501455580012     2025
# 169     NaN  4753960000714648       RENU  JOSHI  0209500025415035     2025
#
#      EXPIR_DATE  CARD_ID
# 3    2029-02-17  1299090
# 45   2029-02-17  1298393
# 69   2029-02-17  1298437
# 113  2029-02-17  1298519
# 169  2029-02-17  1298630
# ✅ Results saved to 'mismatched_output.xlsx', 'duplicate_matches.csv', 'mismatched_lengths.csv', and 'matched_unique.csv'

# %%
import os
import re
import pandas as pd
from datetime import datetime, timedelta

def normalize_name(name):
    """Normalize a name by converting to uppercase, removing extra spaces, and splitting into components"""
    if pd.isna(name) or name == "NaN":
        return {"first": "", "middle": "", "surname": ""}
    name = " ".join(name.split()).upper()
    parts = name.split()
    if len(parts) == 1:
        return {"first": parts[0], "middle": "", "surname": ""}
    elif len(parts) == 2:
        return {"first": parts[0], "middle": "", "surname": parts[1]}
    else:
        return {"first": parts[0], "middle": " ".join(parts[1:-1]), "surname": parts[-1]}

# --- Process Extracted Names ---
multiple_txt_files = input("Do you have multiple text files for name extraction? (yes/no): ").lower().strip()
all_extracted_names = []
line_number = 0

if multiple_txt_files == 'yes':
    txt_paths = []
    while True:
        path = input("Please enter the path to a text file (or 'done' to finish): ")
        if path.lower() == 'done':
            break
        if os.path.exists(path):
            txt_paths.append(path)
    for txt_path in txt_paths:
        with open(txt_path, 'r', encoding='utf-8') as txt_file:
            for line in txt_file:
                line_number += 1
                matches = re.findall(r'NPR\s{0,4}([A-Z][A-Z.\s]+)', line)
                if matches:
                    for match in matches:
                        all_extracted_names.append(match.strip())
                else:
                    all_extracted_names.append("NaN")
else:
    txt_path = input("Please enter the path to your text file: ")
    if os.path.exists(txt_path):
        with open(txt_path, 'r', encoding='utf-8') as txt_file:
            for line in txt_file:
                line_number += 1
                matches = re.findall(r'NPR\s{0,4}([A-Z][A-Z.\s]+)', line)
                if matches:
                    for match in matches:
                        all_extracted_names.append(match.strip())
                else:
                    all_extracted_names.append("NaN")

extracted_df = pd.DataFrame({'EXTRACTED_NAME': all_extracted_names})

# --- Process HCS Files ---
multiple_hcs_files = input("Do you have multiple HCS files to process? (yes/no): ").lower().strip()
all_hcs_data = []

if multiple_hcs_files == 'yes':
    hcs_paths = []
    while True:
        path = input("Please enter the path to an HCS file (or 'done' to finish): ")
        if path.lower() == 'done':
            break
        if os.path.exists(path):
            hcs_paths.append(path)
    for hcs_path in hcs_paths:
        with open(hcs_path, 'r', encoding='utf-8') as file:
            hcs_list = pd.read_html(file.read())
            hcs = hcs_list[0]
            hcs.columns = hcs.iloc[0]
            hcs = hcs[1:].reset_index(drop=True)
            all_hcs_data.append(hcs)
    hcs_df = pd.concat(all_hcs_data, ignore_index=True)
else:
    hcs_path = input("Please enter the path to your HCS file: ")
    if os.path.exists(hcs_path):
        with open(hcs_path, 'r', encoding='utf-8') as file:
            hcs_list = pd.read_html(file.read())
            hcs_df = hcs_list[0]
            hcs_df.columns = hcs_df.iloc[0]
            hcs_df = hcs_df[1:].reset_index(drop=True)

# --- Name Matching ---
hcs_name_col = 'E_NAME'  # HCS Name (E_Name)
account_col = 'ACCOUNT'  # ATM_ACCT
pan_col = 'PAN'  # CARD_NUMBER (adjust if different)
card_code_col = 'CAR_CODE'  # CARD_ID (adjust if different)
expiry_date_col = 'EXPIRYDATE'  # EXPIR_DATE (adjust if different)
# Normalize names
hcs_df['norm'] = hcs_df[hcs_name_col].apply(normalize_name)
extracted_df['norm'] = extracted_df['EXTRACTED_NAME'].apply(normalize_name)

# Create matching keys
hcs_df['match_key'] = hcs_df['norm'].apply(lambda x: f"{x['first']}|{x['middle']}|{x['surname']}")
extracted_df['match_key'] = extracted_df['norm'].apply(lambda x: f"{x['first']}|{x['middle']}|{x['surname']}")

# Merge with extracted_df as base
matched_df = extracted_df.merge(
    hcs_df,
    how='left',
    on='match_key',
    suffixes=('_extracted', '_hcs')
)
matched_df['MATCHED_EXTRACTED_NAME'] = matched_df['EXTRACTED_NAME']

# Keep only rows with HCS matches
matched_df = matched_df.dropna(subset=[hcs_name_col])

# --- Deduplication and Splitting ---
duplicate_mask = matched_df.duplicated(subset=['EXTRACTED_NAME', account_col], keep=False)
duplicate_df = matched_df[duplicate_mask].drop(columns=['norm_extracted', 'norm_hcs', 'match_key'])
unique_df = matched_df[~duplicate_mask].drop(columns=['norm_extracted', 'norm_hcs', 'match_key'])

# --- Compare E_Name and EXTRACTED_NAME in unique_df ---
def check_length_match(row):
    hcs_name = str(row[hcs_name_col]) if pd.notna(row[hcs_name_col]) else ""
    extracted_name = str(row['EXTRACTED_NAME']) if pd.notna(row['EXTRACTED_NAME']) else ""
    return len(hcs_name) == len(extracted_name)

unique_df['length_match'] = unique_df.apply(check_length_match, axis=1)
mismatched_df = unique_df[~unique_df['length_match']].drop(columns=['length_match'])
matched_unique_df = unique_df[unique_df['length_match']].drop(columns=['length_match'])

# --- Generate Excel Output for mismatched_df ---
output_columns = ['ISSTYPE', 'CARD_NUMBER', 'CRDH_NAME', 'ATM_ACCT', 'ISS_DATE', 'EXPIR_DATE', 'CARD_ID']
output_df = pd.DataFrame(columns=output_columns)

# Populate values
output_df['ISSTYPE'] = 'NEW'  # Changed to uppercase
output_df['CARD_NUMBER'] = mismatched_df[pan_col]
output_df['CRDH_NAME'] = mismatched_df['EXTRACTED_NAME']
output_df['ATM_ACCT'] = mismatched_df[account_col]
output_df['EXPIR_DATE'] = pd.to_datetime(mismatched_df[expiry_date_col]).dt.strftime('%Y-%m-%d')
output_df['ISS_DATE'] = (pd.to_datetime(mismatched_df[expiry_date_col]) - timedelta(days=4*365)).dt.strftime('%Y-%m-%d')  # Full date, 4-year gap
output_df['CARD_ID'] = mismatched_df.get(card_code_col, '')

# --- Output Handling ---
print(f"Current working directory: {os.getcwd()}")
output_dir = input("Enter output directory (press Enter for current directory): ").strip() or os.getcwd()

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

duplicate_path = os.path.join(output_dir, 'duplicate_matches.csv')
mismatched_csv_path = os.path.join(output_dir, 'mismatched_lengths.csv')
matched_unique_path = os.path.join(output_dir, 'matched_unique.csv')
excel_path = os.path.join(output_dir, 'mismatched_output.xlsx')

# Results
print(f"\nOriginal HCS rows: {len(hcs_df)}")
print(f"Extracted names: {len(extracted_df)}")
print(f"Matched rows before splitting: {len(matched_df)}")
print(f"Rows with duplicate ACCOUNT and EXTRACTED_NAME: {len(duplicate_df)}")
print(f"Unique or non-duplicate rows: {len(unique_df)}")
print(f"Rows with mismatched lengths in unique_df: {len(mismatched_df)}")
print(f"Rows with matched lengths in unique_df: {len(matched_unique_df)}")
print("\nFirst few rows of Excel output DataFrame:")
print(output_df.head())

# Save files with error handling
try:
    output_df.to_excel(excel_path, index=False)
    duplicate_df.to_csv(duplicate_path, index=False)
    mismatched_df.to_csv(mismatched_csv_path, index=False)
    matched_unique_df.to_csv(matched_unique_path, index=False)
    print(f"✅ Results saved to:\n- {excel_path}\n- {duplicate_path}\n- {mismatched_csv_path}\n- {matched_unique_path}")
except PermissionError as e:
    print(f"❌ PermissionError: {e}")
    print("Please close any open files or run the script with appropriate permissions.")
except Exception as e:
    print(f"❌ Error saving files: {e}")
# Out:
# Do you have multiple text files for name extraction? (yes/no): yes
# Please enter the path to a text file (or 'done' to finish): data\216.txt
# Please enter the path to a text file (or 'done' to finish): data\227.txt
# Please enter the path to a text file (or 'done' to finish): done
# Do you have multiple HCS files to process? (yes/no): no
# Please enter the path to your HCS file: data\hcs.xls
# Current working directory: C:\Users\Surface Pro\Desktop\ATM\card-map-main\final
# Enter output directory (press Enter for current directory):
#
# Original HCS rows: 2464
# Extracted names: 796
# Matched rows before splitting: 819
# Rows with duplicate ACCOUNT and EXTRACTED_NAME: 26
# Unique or non-duplicate rows: 793
# Rows with mismatched lengths in unique_df: 37
# Rows with matched lengths in unique_df: 756
#
# First few rows of Excel output DataFrame:
#     ISSTYPE       CARD_NUMBER         CRDH_NAME          ATM_ACCT    ISS_DATE  \
# 3       NaN  4753960000713079  RAGHUNATH  JOSHI  0100200391375018  2025-02-18
# 45      NaN  4753960000713459     KUMAR  SHERPA  0601100357337013  2025-02-18
# 69      NaN  4753960000713681  MANISHA  DEVKOTA  0509201030652015  2025-02-18
# 113     NaN  4753960000714101    BABURAM  NEPAL  0424501455580012  2025-02-18
# 169     NaN  4753960000714648       RENU  JOSHI  0209500025415035  2025-02-18
#
#      EXPIR_DATE  CARD_ID
# 3    2029-02-17  1299090
# 45   2029-02-17  1298393
# 69   2029-02-17  1298437
# 113  2029-02-17  1298519
# 169  2029-02-17  1298630
# ✅ Results saved to:
# - C:\Users\Surface Pro\Desktop\ATM\card-map-main\final\mismatched_output.xlsx
# - C:\Users\Surface Pro\Desktop\ATM\card-map-main\final\duplicate_matches.csv
# - C:\Users\Surface Pro\Desktop\ATM\card-map-main\final\mismatched_lengths.csv
# - C:\Users\Surface Pro\Desktop\ATM\card-map-main\final\matched_unique.csv

# %%
import os
import re
import pandas as pd
from datetime import datetime, timedelta

def normalize_name(name):
    """Normalize a name by converting to uppercase, removing extra spaces, and splitting into components"""
    if pd.isna(name) or name == "NaN":
        return {"first": "", "middle": "", "surname": ""}
    name = " ".join(name.split()).upper()
    parts = name.split()
    if len(parts) == 1:
        return {"first": parts[0], "middle": "", "surname": ""}
    elif len(parts) == 2:
        return {"first": parts[0], "middle": "", "surname": parts[1]}
    else:
        return {"first": parts[0], "middle": " ".join(parts[1:-1]), "surname": parts[-1]}

# --- Process Extracted Names ---
multiple_txt_files = input("Do you have multiple text files for name extraction? (yes/no): ").lower().strip()
all_extracted_names = []
line_number = 0

if multiple_txt_files == 'yes':
    txt_paths = []
    while True:
        path = input("Please enter the path to a text file (or 'done' to finish): ")
        if path.lower() == 'done':
            break
        if os.path.exists(path):
            txt_paths.append(path)
    for txt_path in txt_paths:
        with open(txt_path, 'r', encoding='utf-8') as txt_file:
            for line in txt_file:
                line_number += 1
                matches = re.findall(r'NPR\s{0,4}([A-Z][A-Z.\s]+)', line)
                if matches:
                    for match in matches:
                        all_extracted_names.append(match.strip())
                else:
                    all_extracted_names.append("NaN")
else:
    txt_path = input("Please enter the path to your text file: ")
    if os.path.exists(txt_path):
        with open(txt_path, 'r', encoding='utf-8') as txt_file:
            for line in txt_file:
                line_number += 1
                matches = re.findall(r'NPR\s{0,4}([A-Z][A-Z.\s]+)', line)
                if matches:
                    for match in matches:
                        all_extracted_names.append(match.strip())
                else:
                    all_extracted_names.append("NaN")

extracted_df = pd.DataFrame({'EXTRACTED_NAME': all_extracted_names})

# --- Process HCS Files ---
multiple_hcs_files = input("Do you have multiple HCS files to process? (yes/no): ").lower().strip()
all_hcs_data = []

if multiple_hcs_files == 'yes':
    hcs_paths = []
    while True:
        path = input("Please enter the path to an HCS file (or 'done' to finish): ")
        if path.lower() == 'done':
            break
        if os.path.exists(path):
            hcs_paths.append(path)
    for hcs_path in hcs_paths:
        with open(hcs_path, 'r', encoding='utf-8') as file:
            hcs_list = pd.read_html(file.read())
            hcs = hcs_list[0]
            hcs.columns = hcs.iloc[0]
            hcs = hcs[1:].reset_index(drop=True)
            all_hcs_data.append(hcs)
    hcs_df = pd.concat(all_hcs_data, ignore_index=True)
else:
    hcs_path = input("Please enter the path to your HCS file: ")
    if os.path.exists(hcs_path):
        with open(hcs_path, 'r', encoding='utf-8') as file:
            hcs_list = pd.read_html(file.read())
            hcs_df = hcs_list[0]
            hcs_df.columns = hcs_df.iloc[0]
            hcs_df = hcs_df[1:].reset_index(drop=True)

# --- Name Matching ---
hcs_name_col = 'E_NAME'  # HCS Name (E_Name)
account_col = 'ACCOUNT'  # ATM_ACCT
pan_col = 'PAN'  # CARD_NUMBER (adjust if different)
card_code_col = 'CAR_CODE'  # CARD_ID (adjust if different)
expiry_date_col = 'EXPIRYDATE'  # EXPIR_DATE (adjust if different)

# Normalize names
hcs_df['norm'] = hcs_df[hcs_name_col].apply(normalize_name)
extracted_df['norm'] = extracted_df['EXTRACTED_NAME'].apply(normalize_name)

# Create matching keys
hcs_df['match_key'] = hcs_df['norm'].apply(lambda x: f"{x['first']}|{x['middle']}|{x['surname']}")
extracted_df['match_key'] = extracted_df['norm'].apply(lambda x: f"{x['first']}|{x['middle']}|{x['surname']}")

# Merge with extracted_df as base
matched_df = extracted_df.merge(
    hcs_df,
    how='left',
    on='match_key',
    suffixes=('_extracted', '_hcs')
)
matched_df['MATCHED_EXTRACTED_NAME'] = matched_df['EXTRACTED_NAME']

# Keep only rows with HCS matches
matched_df = matched_df.dropna(subset=[hcs_name_col])

# --- Deduplication and Splitting ---
duplicate_mask = matched_df.duplicated(subset=['EXTRACTED_NAME', account_col], keep=False)
duplicate_df = matched_df[duplicate_mask].drop(columns=['norm_extracted', 'norm_hcs', 'match_key'])
unique_df = matched_df[~duplicate_mask].drop(columns=['norm_extracted', 'norm_hcs', 'match_key'])

# --- Compare E_Name and EXTRACTED_NAME in unique_df ---
def check_length_match(row):
    hcs_name = str(row[hcs_name_col]) if pd.notna(row[hcs_name_col]) else ""
    extracted_name = str(row['EXTRACTED_NAME']) if pd.notna(row['EXTRACTED_NAME']) else ""
    return len(hcs_name) == len(extracted_name)

unique_df['length_match'] = unique_df.apply(check_length_match, axis=1)
mismatched_df = unique_df[~unique_df['length_match']].drop(columns=['length_match'])
matched_unique_df = unique_df[unique_df['length_match']].drop(columns=['length_match'])

# --- Generate Excel Output for mismatched_df ---
output_columns = ['ISSTYPE', 'CARD_NUMBER', 'CRDH_NAME', 'ATM_ACCT', 'ISS_DATE', 'EXPIR_DATE', 'CARD_ID']

# Initialize output_df with the same number of rows as mismatched_df
output_df = pd.DataFrame(index=mismatched_df.index, columns=output_columns)

# Populate values
output_df['ISSTYPE'] = 'NEW'  # Changed to uppercase
output_df['CARD_NUMBER'] = mismatched_df[pan_col]
output_df['CRDH_NAME'] = mismatched_df['EXTRACTED_NAME']
output_df['ATM_ACCT'] = mismatched_df[account_col]
output_df['EXPIR_DATE'] = pd.to_datetime(mismatched_df[expiry_date_col]).dt.strftime('%Y-%m-%d')
output_df['ISS_DATE'] = (pd.to_datetime(mismatched_df[expiry_date_col]) - timedelta(days=4*365)).dt.strftime('%Y-%m-%d')
output_df['CARD_ID'] = mismatched_df.get(card_code_col, '')

# --- Output Handling ---
print(f"Current working directory: {os.getcwd()}")
output_dir = input("Enter output directory (press Enter for current directory): ").strip() or os.getcwd()

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

duplicate_path = os.path.join(output_dir, 'duplicate_matches.csv')
mismatched_csv_path = os.path.join(output_dir, 'mismatched_lengths.csv')
matched_unique_path = os.path.join(output_dir, 'matched_unique.csv')
excel_path = os.path.join(output_dir, 'mismatched_output.xlsx')

# Results
print(f"\nOriginal HCS rows: {len(hcs_df)}")
print(f"Extracted names: {len(extracted_df)}")
print(f"Matched rows before splitting: {len(matched_df)}")
print(f"Rows with duplicate ACCOUNT and EXTRACTED_NAME: {len(duplicate_df)}")
print(f"Unique or non-duplicate rows: {len(unique_df)}")
print(f"Rows with mismatched lengths in unique_df: {len(mismatched_df)}")
print(f"Rows with matched lengths in unique_df: {len(matched_unique_df)}")
print("\nFirst few rows of Excel output DataFrame:")
print(output_df.head())

# Save files with error handling
try:
    output_df.to_excel(excel_path, index=False)
    duplicate_df.to_csv(duplicate_path, index=False)
    mismatched_df.to_csv(mismatched_csv_path, index=False)
    matched_unique_df.to_csv(matched_unique_path, index=False)
    print(f"✅ Results saved to:\n- {excel_path}\n- {duplicate_path}\n- {mismatched_csv_path}\n- {matched_unique_path}")
except PermissionError as e:
    print(f"❌ PermissionError: {e}")
    print("Please close any open files or run the script with appropriate permissions.")
except Exception as e:
    print(f"❌ Error saving files: {e}")
# Out:
# Do you have multiple text files for name extraction? (yes/no):  yes
# Please enter the path to a text file (or 'done' to finish):  today.txt
# Please enter the path to a text file (or 'done' to finish):  today1.txt
# Please enter the path to a text file (or 'done' to finish):  today2.txt
# Please enter the path to a text file (or 'done' to finish):  today3.txt
# Please enter the path to a text file (or 'done' to finish):  done
